# %% [markdown]
# <a href="https://colab.research.google.com/github/abuebayyeh/imperial_eee_machine_learning_course/blob/main/05_ML_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multilayer Perceptron (MLP)
#
#
# ---
#
#
# Multilayer perceptron (MLP) networks are one of the most commonly used networks, they are also considered as feed-forward networks. The development of the back-propagation learning algorithm for determining weights was the main reason behind the popularity of these networks among researchers. As the name suggests, an MLP consists of multiple perceptrons arranged into a number of layers in order to deal with complex problems. A typical MLP consists of an input layer, hidden layer(s) and an output layer. The units (neurons) in each layer are fully connected to the following layer. MLPs are usually described according to the number of neurons and layers used. For example, a 3-5-4 MLP is a two-layer network consisting of an input layer with three inputs, a hidden layer with five neurons and an output layer with four outputs. The figure below represent a 4-layer MLP (Note: the input layer is not counted as a layer).
#
#
# ![nnmlp.png](data:image/png;base64,...)
#
# The feedforward operation is shown in the diagram below. Each neuron multiplies its inputs $a$ with corresponding weights $w$. The activation function $\theta$ is used to add non-linearity to the process and allows it to learn complex data sets (the network is equivalent to one linear transformation without these non-linearities - try to show this!). The activation function is applied after multiplying the weights with the inputs and summing the results.
#
#
# ![nnop.png](data:image/png;base64,...)
#
# Many activation functions can be used in MLP depending on the problem being investigated. In the figure below are some examples of common activation functions.
#
# ![af1.png](data:image/png;base64,...)
#
# ![af2.png](data:image/png;base64,...)
#
# Many forms of cost functions $J$ to measure the error are available as mentioned in the previous tutorials. The objective of this process is to get the optimal set of tunable parameters (weights and biases) that will minimise the cost $J$. Back-propagation and gradient descent are used to apply these optimisation steps in a systematic manner such that the weights and biases are updated using the derivative and chain-rule concepts as described in the equations below.
#
#
# \begin{aligned}
#     \Delta w_i=-\alpha \frac{\partial J}{\partial w_i} \\
#     w_{i}(t+1)=w_i(t)+\Delta w_i
# \end{aligned}
#
#
#
# The hyperparameter $\alpha$ is called the learning rate which is selected before the training takes place. If the value of $\alpha$ is too high, the algorithm may learn faster; however, it may diverge in reaching the minimal value resulting in oscillating behaviour. On the other hand, if the value of $\alpha$ is too small, the learning process will be slow but more stable. Parameter $t$ refers to the number of iterations (equivalent to number of epochs if update is calculated over entire dataset) where the weights are updated. At the start of training, the weights are usually given random values.

# %% [markdown]
# # MNIST Dataset
#
# In this notebook, we will use a common open access dataset called Modified National Institute of Standards and Technology (MNIST) shown in Figure below.
#
# ![mnist.png](data:image/png;base64,...)
#
#
# This data contains 70,000 scanned images of handwritten digits, together with their correct labels. These images are scanned handwriting samples from 250 people, half of whom were US Census Bureau employees, and the other half were high school students. The images are in grayscale format and of size $28\times 28$ pixels each. The labels are in integer format such that each image has the correct corresponding label that describes it as a number from 0 to 9. The MNIST data is divided into two parts. The first part is the training data that contains 60,000 images. The second part is the test data that contains 10,000 images.
#
# ## The code below is from "Python Machine Learning," Sebastian Raschka, Packt Publishing, 2015 (page 356), with modifications.

# %%
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
import sys
import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From C:\Users\chang\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Importing the data from tensoflow library into train and test.
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
# Displaying samples of the 10 classes in this data

fig = plt.figure()
for i in range(10):
    plt.subplot(2, 5, i+1)
    x_y = X_train[y_train == i]
    plt.imshow(x_y[0], cmap='gray', interpolation='none')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

plt.tight_layout()

# %%
# Displaying different samples of the same class.
print("Samples of class 3:")
fig = plt.figure()

for i in range(10):
    plt.subplot(2, 5, i+1)
    x_y = X_train[y_train == 3]
    plt.imshow(x_y[i], cmap='gray', interpolation='none')
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
# Out:
# Samples of class 3:

# %% [markdown]
# Before the images are fed to the MLP, they should go through simple pre-processing steps. First, the pixel values are scaled (normalised) to have values between 0 and 1. In order to do that, all the pixel values are divided by 255 (MNIST grayscale images have 256 different gray values, numbered 0 - 255 (8 bits)). This improves learning stability. Secondly, the image should be flattened to a vector format as the MLP takes a vector with each input corresponding to a pixel location.
#
# ![vectorise.png](data:image/png;base64,...)

# %%
print('X_train.shape', X_train.shape)
print('X_test.shape', X_test.shape)
# reshaping the inputs
X_train = X_train.reshape(60000, 28*28)
X_test = X_test.reshape(10000, 28*28)
# normalizing the inputs (-1, 1)
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
print('X_train reshape:', X_train.shape)
print('X_test reshape:', X_test.shape)
# Out:
# X_train.shape (60000, 28, 28)
# X_test.shape (10000, 28, 28)
# X_train reshape: (60000, 784)
# X_test reshape: (10000, 784)

# %%
# Create a random permutation of indices
num_train_samples = len(X_train)
num_test_samples = len(X_test)

train_indices = np.random.permutation(num_train_samples)
test_indices = np.random.permutation(num_test_samples)

# Shuffle the data using the permutation of indices
X_train = X_train[train_indices]
y_train = y_train[train_indices]

X_test = X_test[test_indices]
y_test = y_test[test_indices]

# %% [markdown]
# The MNIST data does not include validation dataset; however, we can use part of the training set for validation as follows:

# %%
X_valid=X_train[:5000]
y_valid=y_train[:5000]
X_train=X_train[5000:60000]
y_train=y_train[5000:60000]

# %%
class NeuralNetMLP(object):
    """ Feedforward neural network / Multi-layer perceptron classifier.

    Parameters
    ------------
    n_hidden : int (default: 30)
        Number of hidden units.
    l2 : float (default: 0.)
        Lambda value for L2-regularization.
        No regularization if l2=0. (default)
    epochs : int (default: 100)
        Number of passes over the training set.
    alpha : float (default: 0.001)
        Learning rate.
    shuffle : bool (default: True)
        Shuffles training data every epoch if True to prevent circles.
    minibatch_size : int (default: 1)
        Number of training examples per minibatch.
    seed : int (default: None)
        Random seed for initializing weights and shuffling.

    Attributes
    -----------
    eval_ : dict
      Dictionary collecting the cost, training accuracy,
      and validation accuracy for each epoch during training.

    """
    def __init__(self, n_hidden=30,
                 l2=0., epochs=100, alpha=0.001,
                 shuffle=True, minibatch_size=1, seed=None,
                 activation="sigmoid"):

        self.random = np.random.RandomState(seed)
        self.n_hidden = n_hidden
        self.l2 = l2
        self.epochs = epochs
        self.alpha = alpha
        self.shuffle = shuffle
        self.minibatch_size = minibatch_size
        if activation == "sigmoid":
            self.act = self._sigmoid
            self.act_deriv = lambda a_h: a_h * (1. - a_h)

        ##########################################################################
        #### Task 1:
        #### you can continue your code here to use different activation functions.
        #### adjust the previous conditional statments such that you add cases of
        #### other activation functions.
        ##########################################################################


    def _onehot(self, y, n_classes):
        """Encode labels into one-hot representation

        Parameters
        ------------
        y : array, shape = [n_examples]
            Target values.
        n_classes : int
            Number of classes

        Returns
        -----------
        onehot : array, shape = (n_examples, n_labels)

        """
        onehot = np.zeros((n_classes, y.shape[0]))
        for idx, val in enumerate(y.astype(int)):
            onehot[val, idx] = 1.
        return onehot.T

    def _sigmoid(self, z):
        """Compute logistic function (sigmoid)"""
        return 1. / (1. + np.exp(-np.clip(z, -250, 250)))

    def _forward(self, X):
        """Compute forward propagation step"""

        # step 1: net input of hidden layer
        # [n_examples, n_features] dot [n_features, n_hidden]
        # -> [n_examples, n_hidden]
        z_h = np.dot(X, self.w_h) + self.b_h

        # step 2: activation of hidden layer
        a_h = self.act(z_h)

        # step 3: net input of output layer
        # [n_examples, n_hidden] dot [n_hidden, n_classlabels]
        # -> [n_examples, n_classlabels]

        z_out = np.dot(a_h, self.w_out) + self.b_out

        # step 4: activation output layer
        a_out = self._sigmoid(z_out)

        return z_h, a_h, z_out, a_out

    def _compute_cost(self, y_enc, output):
        """Compute cost function.

        Parameters
        ----------
        y_enc : array, shape = (n_examples, n_labels)
            one-hot encoded class labels.
        output : array, shape = [n_examples, n_output_units]
            Activation of the output layer (forward propagation)

        Returns
        ---------
        cost : float
            Regularized cost

        """
        L2_term = (self.l2 *
                   (np.sum(self.w_h ** 2.) +
                    np.sum(self.w_out ** 2.)))

        term1 = -y_enc * (np.log(output))
        term2 = (1. - y_enc) * np.log(1. - output)
        cost = np.sum(term1 - term2) + L2_term

        # If you are applying this cost function to other
        # datasets where activation
        # values maybe become more extreme (closer to zero or 1)
        # you may encounter "ZeroDivisionError"s due to numerical
        # instabilities in Python & NumPy for the current implementation.
        # I.e., the code tries to evaluate log(0), which is undefined.
        # To address this issue, you could add a small constant to the
        # activation values that are passed to the log function.
        #
        # For example:
        #
        # term1 = -y_enc * (np.log(output + 1e-5))
        # term2 = (1. - y_enc) * np.log(1. - output + 1e-5)

        return cost

    def predict(self, X):
        """Predict class labels

        Parameters
        -----------
        X : array, shape = [n_examples, n_features]
            Input layer with original features.

        Returns:
        ----------
        y_pred : array, shape = [n_examples]
            Predicted class labels.

        """
        z_h, a_h, z_out, a_out = self._forward(X)
        y_pred = np.argmax(z_out, axis=1)
        return y_pred

    def fit(self, X_train, y_train, X_valid, y_valid):
        """ Learn weights from training data.

        Parameters
        -----------
        X_train : array, shape = [n_examples, n_features]
            Input layer with original features.
        y_train : array, shape = [n_examples]
            Target class labels.
        X_valid : array, shape = [n_examples, n_features]
            Sample features for validation during training
        y_valid : array, shape = [n_examples]
            Sample labels for validation during training

        Returns:
        ----------
        self

        """
        n_output = np.unique(y_train).shape[0]  # number of class labels
        n_features = X_train.shape[1]

        ########################
        # Weight initialization
        ########################

        # weights for input -> hidden
        self.b_h = np.zeros(self.n_hidden)
        self.w_h = self.random.normal(loc=0.0, scale=0.1,
                                      size=(n_features, self.n_hidden))

        # weights for hidden -> output
        self.b_out = np.zeros(n_output)
        self.w_out = self.random.normal(loc=0.0, scale=0.1,
                                        size=(self.n_hidden, n_output))

        epoch_strlen = len(str(self.epochs))  # for progress formatting
        self.eval_ = {'cost': [], 'train_acc': [], 'valid_acc': []}

        y_train_enc = self._onehot(y_train, n_output)

        # iterate over training epochs
        for i in range(self.epochs):

            # iterate over minibatches
            indices = np.arange(X_train.shape[0])

            if self.shuffle:
                self.random.shuffle(indices)

            for start_idx in range(0, indices.shape[0] - self.minibatch_size +
                                   1, self.minibatch_size):
                batch_idx = indices[start_idx:start_idx + self.minibatch_size]

                # forward propagation
                z_h, a_h, z_out, a_out = self._forward(X_train[batch_idx])

                ##################
                # Backpropagation
                ##################

                # [n_examples, n_classlabels]
                delta_out = a_out - y_train_enc[batch_idx]

                # [n_examples, n_hidden]
                act_derivative_h = self.act_deriv(a_h)

                # [n_examples, n_classlabels] dot [n_classlabels, n_hidden]
                # -> [n_examples, n_hidden]
                delta_h = (np.dot(delta_out, self.w_out.T) *
                           act_derivative_h)

                # [n_features, n_examples] dot [n_examples, n_hidden]
                # -> [n_features, n_hidden]
                grad_w_h = np.dot(X_train[batch_idx].T, delta_h)
                grad_b_h = np.sum(delta_h, axis=0)

                # [n_hidden, n_examples] dot [n_examples, n_classlabels]
                # -> [n_hidden, n_classlabels]
                grad_w_out = np.dot(a_h.T, delta_out)
                grad_b_out = np.sum(delta_out, axis=0)

                # Regularization and weight updates
                delta_w_h = (grad_w_h + self.l2*self.w_h)
                delta_b_h = grad_b_h # bias is not regularized
                self.w_h -= self.alpha * delta_w_h
                self.b_h -= self.alpha * delta_b_h

                delta_w_out = (grad_w_out + self.l2*self.w_out)
                delta_b_out = grad_b_out  # bias is not regularized
                self.w_out -= self.alpha * delta_w_out
                self.b_out -= self.alpha * delta_b_out

            #############
            # Evaluation
            #############

            # Evaluation after each epoch during training
            z_h, a_h, z_out, a_out = self._forward(X_train)

            cost = self._compute_cost(y_enc=y_train_enc,
                                      output=a_out)

            y_train_pred = self.predict(X_train)
            y_valid_pred = self.predict(X_valid)

            train_acc = ((np.sum(y_train == y_train_pred)).astype(np.float) /
                         X_train.shape[0])
            valid_acc = ((np.sum(y_valid == y_valid_pred)).astype(np.float) /
                         X_valid.shape[0])

            print('\r%0*d/%d | Cost: %.2f '
                  '| Train/Valid Acc.: %.2f%%/%.2f%% ' %
                  (epoch_strlen, i+1, self.epochs, cost,
                  train_acc*100, valid_acc*100))
            # sys.stderr.write
            # sys.stderr.flush()

            self.eval_['cost'].append(cost)
            self.eval_['train_acc'].append(train_acc)
            self.eval_['valid_acc'].append(valid_acc)

        return self

# %%
# Executing the algorithm here (it may take some time to execute the code)

n_epochs = 200 # Number of training epochs

for l2i in range(5):
       print('===================================l2: '+str(l2i)+'================================')
       # Initialize a NeuralNet MLP
       nn = NeuralNetMLP(
       n_hidden=100,
       l2=l2i,
       epochs=n_epochs,
       alpha=0.0005,
       minibatch_size=100,
       shuffle=True,
       seed=1,
       activation="sigmoid"
       )

       # Here we use part of the training data for validation such that 55000 data samples for training and the rest 5000
       #for validation
       nn.fit(
       X_train,
       y_train,
       X_valid,
       y_valid
       )

       # plot the cost vs epochs
       plt.plot(range(nn.epochs), nn.eval_['cost'])
       plt.ylabel('Cost')
       plt.xlabel('Epochs')
       plt.show()

       plt.plot(range(nn.epochs), nn.eval_['train_acc'],
              label='Training')
       plt.plot(range(nn.epochs), nn.eval_['valid_acc'],
              label='Validation', linestyle='--')
       plt.ylabel('Accuracy')
       plt.xlabel('Epochs')
       plt.legend(loc='lower right')
       plt.show()

       y_test_pred = nn.predict(X_test)
       acc = (np.sum(y_test == y_test_pred)
              .astype(np.float) / X_test.shape[0])

       print('Test accuracy: %.2f%%' % (acc * 100))

       y_train_pred = nn.predict(X_train)
       acc = (np.sum(y_train == y_train_pred)
              .astype(np.float) / X_train.shape[0])

       print('Train accuracy: %.2f%%' % (acc * 100))

       y_val_pred = nn.predict(X_valid)
       acc = (np.sum(y_valid == y_val_pred)
              .astype(np.float) / X_valid.shape[0])

       print('Val accuracy: %.2f%%' % (acc * 100))
# Out:
# ===================================l2: 0================================
# 001/200 | Cost: 83629.16 | Train/Valid Acc.: 80.80%/80.72%
# 002/200 | Cost: 59980.33 | Train/Valid Acc.: 86.20%/86.04%
# 003/200 | Cost: 50081.10 | Train/Valid Acc.: 87.95%/87.76%
# 004/200 | Cost: 44546.52 | Train/Valid Acc.: 89.06%/89.00%
# 005/200 | Cost: 40970.64 | Train/Valid Acc.: 89.75%/89.62%
# 006/200 | Cost: 38439.98 | Train/Valid Acc.: 90.18%/90.02%
# 007/200 | Cost: 36460.69 | Train/Valid Acc.: 90.59%/90.20%
# 008/200 | Cost: 34834.06 | Train/Valid Acc.: 90.99%/90.62%
# 009/200 | Cost: 33536.35 | Train/Valid Acc.: 91.27%/90.84%
# 010/200 | Cost: 32368.57 | Train/Valid Acc.: 91.59%/91.04%
# 011/200 | Cost: 31308.77 | Train/Valid Acc.: 91.83%/91.22%
# 012/200 | Cost: 30371.46 | Train/Valid Acc.: 92.12%/91.34%
# 013/200 | Cost: 29482.75 | Train/Valid Acc.: 92.33%/91.62%
# 014/200 | Cost: 28701.73 | Train/Valid Acc.: 92.55%/91.96%
# 015/200 | Cost: 27911.97 | Train/Valid Acc.: 92.76%/92.14%
# 016/200 | Cost: 27236.94 | Train/Valid Acc.: 92.89%/92.28%
# 017/200 | Cost: 26597.58 | Train/Valid Acc.: 93.02%/92.38%
# 018/200 | Cost: 26008.62 | Train/Valid Acc.: 93.23%/92.46%
# 019/200 | Cost: 25473.93 | Train/Valid Acc.: 93.33%/92.64%
# 020/200 | Cost: 24888.12 | Train/Valid Acc.: 93.51%/92.78%
# 021/200 | Cost: 24384.99 | Train/Valid Acc.: 93.69%/92.80%
# 022/200 | Cost: 23890.48 | Train/Valid Acc.: 93.80%/92.90%
# 023/200 | Cost: 23465.22 | Train/Valid Acc.: 93.94%/92.96%
# 024/200 | Cost: 23061.82 | Train/Valid Acc.: 94.04%/93.14%
# 025/200 | Cost: 22597.37 | Train/Valid Acc.: 94.15%/93.20%
# 026/200 | Cost: 22205.03 | Train/Valid Acc.: 94.27%/93.22%
# 027/200 | Cost: 21837.07 | Train/Valid Acc.: 94.33%/93.34%
# 028/200 | Cost: 21482.28 | Train/Valid Acc.: 94.48%/93.54%
# 029/200 | Cost: 21093.67 | Train/Valid Acc.: 94.57%/93.56%
# 030/200 | Cost: 20771.01 | Train/Valid Acc.: 94.68%/93.46%
# 031/200 | Cost: 20471.98 | Train/Valid Acc.: 94.76%/93.68%
# 032/200 | Cost: 20129.25 | Train/Valid Acc.: 94.86%/93.88%
# 033/200 | Cost: 19816.01 | Train/Valid Acc.: 94.92%/93.94%
# 034/200 | Cost: 19565.38 | Train/Valid Acc.: 94.97%/94.02%
# 035/200 | Cost: 19267.33 | Train/Valid Acc.: 95.02%/94.16%
# 036/200 | Cost: 18986.89 | Train/Valid Acc.: 95.13%/94.14%
# 037/200 | Cost: 18732.72 | Train/Valid Acc.: 95.21%/94.26%
# 038/200 | Cost: 18454.24 | Train/Valid Acc.: 95.27%/94.28%
# 039/200 | Cost: 18213.52 | Train/Valid Acc.: 95.31%/94.28%
# 040/200 | Cost: 17966.73 | Train/Valid Acc.: 95.42%/94.40%
# 041/200 | Cost: 17733.94 | Train/Valid Acc.: 95.48%/94.44%
# 042/200 | Cost: 17512.96 | Train/Valid Acc.: 95.56%/94.56%
# 043/200 | Cost: 17315.12 | Train/Valid Acc.: 95.59%/94.58%
# 044/200 | Cost: 17089.92 | Train/Valid Acc.: 95.66%/94.68%
# 045/200 | Cost: 16865.95 | Train/Valid Acc.: 95.73%/94.64%
# 046/200 | Cost: 16659.85 | Train/Valid Acc.: 95.80%/94.66%
# 047/200 | Cost: 16456.27 | Train/Valid Acc.: 95.84%/94.70%
# 048/200 | Cost: 16287.75 | Train/Valid Acc.: 95.91%/94.78%
# 049/200 | Cost: 16082.99 | Train/Valid Acc.: 95.98%/94.82%
# 050/200 | Cost: 15900.08 | Train/Valid Acc.: 96.08%/94.84%
# 051/200 | Cost: 15719.71 | Train/Valid Acc.: 96.12%/94.84%
# 052/200 | Cost: 15559.41 | Train/Valid Acc.: 96.20%/94.88%
# 053/200 | Cost: 15375.99 | Train/Valid Acc.: 96.22%/94.86%
# 054/200 | Cost: 15203.23 | Train/Valid Acc.: 96.29%/94.96%
# 055/200 | Cost: 15054.98 | Train/Valid Acc.: 96.31%/94.98%
# 056/200 | Cost: 14897.95 | Train/Valid Acc.: 96.32%/95.16%
# 057/200 | Cost: 14722.81 | Train/Valid Acc.: 96.40%/95.10%
# 058/200 | Cost: 14604.81 | Train/Valid Acc.: 96.42%/95.14%
# 059/200 | Cost: 14452.26 | Train/Valid Acc.: 96.49%/95.14%
# 060/200 | Cost: 14285.69 | Train/Valid Acc.: 96.54%/95.24%
# 061/200 | Cost: 14155.68 | Train/Valid Acc.: 96.56%/95.32%
# 062/200 | Cost: 14011.64 | Train/Valid Acc.: 96.59%/95.26%
# 063/200 | Cost: 13870.04 | Train/Valid Acc.: 96.66%/95.28%
# 064/200 | Cost: 13745.55 | Train/Valid Acc.: 96.73%/95.28%
# 065/200 | Cost: 13599.55 | Train/Valid Acc.: 96.73%/95.44%
# 066/200 | Cost: 13485.06 | Train/Valid Acc.: 96.76%/95.36%
# 067/200 | Cost: 13357.65 | Train/Valid Acc.: 96.81%/95.46%
# 068/200 | Cost: 13219.20 | Train/Valid Acc.: 96.86%/95.44%
# 069/200 | Cost: 13115.25 | Train/Valid Acc.: 96.90%/95.38%
# 070/200 | Cost: 12991.05 | Train/Valid Acc.: 96.92%/95.50%
# 071/200 | Cost: 12897.37 | Train/Valid Acc.: 96.93%/95.56%
# 072/200 | Cost: 12759.37 | Train/Valid Acc.: 97.01%/95.44%
# 073/200 | Cost: 12656.58 | Train/Valid Acc.: 97.01%/95.56%
# 074/200 | Cost: 12548.81 | Train/Valid Acc.: 96.99%/95.56%
# 075/200 | Cost: 12430.13 | Train/Valid Acc.: 97.08%/95.58%
# 076/200 | Cost: 12327.11 | Train/Valid Acc.: 97.11%/95.66%
# 077/200 | Cost: 12240.24 | Train/Valid Acc.: 97.12%/95.70%
# 078/200 | Cost: 12121.85 | Train/Valid Acc.: 97.13%/95.54%
# 079/200 | Cost: 12042.79 | Train/Valid Acc.: 97.15%/95.66%
# 080/200 | Cost: 11928.38 | Train/Valid Acc.: 97.21%/95.74%
# 081/200 | Cost: 11838.29 | Train/Valid Acc.: 97.24%/95.66%
# 082/200 | Cost: 11731.66 | Train/Valid Acc.: 97.26%/95.76%
# 083/200 | Cost: 11640.78 | Train/Valid Acc.: 97.29%/95.72%
# 084/200 | Cost: 11556.77 | Train/Valid Acc.: 97.30%/95.80%
# 085/200 | Cost: 11464.87 | Train/Valid Acc.: 97.33%/95.76%
# 086/200 | Cost: 11378.11 | Train/Valid Acc.: 97.35%/95.80%
# 087/200 | Cost: 11308.53 | Train/Valid Acc.: 97.39%/95.78%
# 088/200 | Cost: 11201.76 | Train/Valid Acc.: 97.44%/95.88%
# 089/200 | Cost: 11110.00 | Train/Valid Acc.: 97.43%/95.94%
# 090/200 | Cost: 11017.62 | Train/Valid Acc.: 97.45%/95.90%
# 091/200 | Cost: 10943.80 | Train/Valid Acc.: 97.48%/95.86%
# 092/200 | Cost: 10860.85 | Train/Valid Acc.: 97.50%/95.92%
# 093/200 | Cost: 10778.48 | Train/Valid Acc.: 97.52%/95.92%
# 094/200 | Cost: 10702.63 | Train/Valid Acc.: 97.56%/96.00%
# 095/200 | Cost: 10630.74 | Train/Valid Acc.: 97.59%/96.00%
# 096/200 | Cost: 10542.47 | Train/Valid Acc.: 97.58%/95.94%
# 097/200 | Cost: 10467.67 | Train/Valid Acc.: 97.60%/96.00%
# 098/200 | Cost: 10402.55 | Train/Valid Acc.: 97.64%/96.02%
# 099/200 | Cost: 10325.66 | Train/Valid Acc.: 97.65%/96.04%
# 100/200 | Cost: 10251.12 | Train/Valid Acc.: 97.67%/96.06%
# 101/200 | Cost: 10194.40 | Train/Valid Acc.: 97.68%/96.04%
# 102/200 | Cost: 10118.58 | Train/Valid Acc.: 97.70%/96.08%
# 103/200 | Cost: 10063.00 | Train/Valid Acc.: 97.73%/96.14%
# 104/200 | Cost: 9986.51 | Train/Valid Acc.: 97.75%/96.10%
# 105/200 | Cost: 9910.83 | Train/Valid Acc.: 97.77%/96.14%
# 106/200 | Cost: 9837.72 | Train/Valid Acc.: 97.79%/96.14%
# 107/200 | Cost: 9782.28 | Train/Valid Acc.: 97.81%/96.14%
# 108/200 | Cost: 9718.43 | Train/Valid Acc.: 97.82%/96.14%
# 109/200 | Cost: 9652.68 | Train/Valid Acc.: 97.83%/96.14%
# 110/200 | Cost: 9585.19 | Train/Valid Acc.: 97.86%/96.14%
# 111/200 | Cost: 9541.20 | Train/Valid Acc.: 97.87%/96.18%
# 112/200 | Cost: 9475.12 | Train/Valid Acc.: 97.90%/96.22%
# 113/200 | Cost: 9413.80 | Train/Valid Acc.: 97.91%/96.22%
# 114/200 | Cost: 9339.39 | Train/Valid Acc.: 97.93%/96.24%
# 115/200 | Cost: 9284.70 | Train/Valid Acc.: 97.96%/96.28%
# 116/200 | Cost: 9245.77 | Train/Valid Acc.: 97.97%/96.30%
# 117/200 | Cost: 9173.88 | Train/Valid Acc.: 97.99%/96.32%
# 118/200 | Cost: 9110.38 | Train/Valid Acc.: 98.03%/96.30%
# 119/200 | Cost: 9070.36 | Train/Valid Acc.: 98.04%/96.32%
# 120/200 | Cost: 8997.91 | Train/Valid Acc.: 98.05%/96.28%
# 121/200 | Cost: 8950.63 | Train/Valid Acc.: 98.06%/96.34%
# 122/200 | Cost: 8910.68 | Train/Valid Acc.: 98.08%/96.34%
# 123/200 | Cost: 8848.11 | Train/Valid Acc.: 98.09%/96.34%
# 124/200 | Cost: 8791.99 | Train/Valid Acc.: 98.10%/96.32%
# 125/200 | Cost: 8737.82 | Train/Valid Acc.: 98.11%/96.34%
# 126/200 | Cost: 8691.98 | Train/Valid Acc.: 98.12%/96.46%
# 127/200 | Cost: 8643.30 | Train/Valid Acc.: 98.13%/96.44%
# 128/200 | Cost: 8580.73 | Train/Valid Acc.: 98.15%/96.44%
# 129/200 | Cost: 8539.08 | Train/Valid Acc.: 98.18%/96.36%
# 130/200 | Cost: 8482.57 | Train/Valid Acc.: 98.17%/96.46%
# 131/200 | Cost: 8432.48 | Train/Valid Acc.: 98.19%/96.48%
# 132/200 | Cost: 8382.27 | Train/Valid Acc.: 98.21%/96.46%
# 133/200 | Cost: 8344.70 | Train/Valid Acc.: 98.22%/96.50%
# 134/200 | Cost: 8302.56 | Train/Valid Acc.: 98.24%/96.50%
# 135/200 | Cost: 8250.35 | Train/Valid Acc.: 98.23%/96.50%
# 136/200 | Cost: 8210.20 | Train/Valid Acc.: 98.25%/96.46%
# 137/200 | Cost: 8178.03 | Train/Valid Acc.: 98.25%/96.46%
# 138/200 | Cost: 8102.88 | Train/Valid Acc.: 98.27%/96.50%
# 139/200 | Cost: 8075.05 | Train/Valid Acc.: 98.30%/96.52%
# 140/200 | Cost: 8016.67 | Train/Valid Acc.: 98.29%/96.60%
# 141/200 | Cost: 7977.64 | Train/Valid Acc.: 98.32%/96.54%
# 142/200 | Cost: 7940.73 | Train/Valid Acc.: 98.33%/96.60%
# 143/200 | Cost: 7890.67 | Train/Valid Acc.: 98.34%/96.58%
# 144/200 | Cost: 7859.78 | Train/Valid Acc.: 98.36%/96.56%
# 145/200 | Cost: 7805.89 | Train/Valid Acc.: 98.35%/96.50%
# 146/200 | Cost: 7765.02 | Train/Valid Acc.: 98.36%/96.56%
# 147/200 | Cost: 7722.02 | Train/Valid Acc.: 98.37%/96.64%
# 148/200 | Cost: 7692.08 | Train/Valid Acc.: 98.39%/96.60%
# 149/200 | Cost: 7649.89 | Train/Valid Acc.: 98.40%/96.60%
# 150/200 | Cost: 7607.61 | Train/Valid Acc.: 98.41%/96.62%
# 151/200 | Cost: 7560.47 | Train/Valid Acc.: 98.42%/96.62%
# 152/200 | Cost: 7524.55 | Train/Valid Acc.: 98.44%/96.58%
# 153/200 | Cost: 7490.75 | Train/Valid Acc.: 98.43%/96.64%
# 154/200 | Cost: 7443.05 | Train/Valid Acc.: 98.47%/96.64%
# 155/200 | Cost: 7406.38 | Train/Valid Acc.: 98.45%/96.64%
# 156/200 | Cost: 7364.90 | Train/Valid Acc.: 98.47%/96.70%
# 157/200 | Cost: 7331.73 | Train/Valid Acc.: 98.49%/96.66%
# 158/200 | Cost: 7295.14 | Train/Valid Acc.: 98.50%/96.70%
# 159/200 | Cost: 7265.58 | Train/Valid Acc.: 98.50%/96.60%
# 160/200 | Cost: 7220.42 | Train/Valid Acc.: 98.52%/96.68%
# 161/200 | Cost: 7192.59 | Train/Valid Acc.: 98.51%/96.72%
# 162/200 | Cost: 7144.74 | Train/Valid Acc.: 98.53%/96.72%
# 163/200 | Cost: 7108.44 | Train/Valid Acc.: 98.52%/96.60%
# 164/200 | Cost: 7074.02 | Train/Valid Acc.: 98.55%/96.66%
# 165/200 | Cost: 7034.80 | Train/Valid Acc.: 98.56%/96.64%
# 166/200 | Cost: 7015.24 | Train/Valid Acc.: 98.55%/96.74%
# 167/200 | Cost: 6988.05 | Train/Valid Acc.: 98.58%/96.74%
# 168/200 | Cost: 6936.16 | Train/Valid Acc.: 98.57%/96.72%
# 169/200 | Cost: 6905.02 | Train/Valid Acc.: 98.58%/96.74%
# 170/200 | Cost: 6882.18 | Train/Valid Acc.: 98.59%/96.72%
# 171/200 | Cost: 6835.31 | Train/Valid Acc.: 98.60%/96.72%
# 172/200 | Cost: 6802.80 | Train/Valid Acc.: 98.61%/96.76%
# 173/200 | Cost: 6780.01 | Train/Valid Acc.: 98.63%/96.74%
# 174/200 | Cost: 6733.79 | Train/Valid Acc.: 98.61%/96.82%
# 175/200 | Cost: 6711.50 | Train/Valid Acc.: 98.62%/96.70%
# 176/200 | Cost: 6676.91 | Train/Valid Acc.: 98.66%/96.76%
# 177/200 | Cost: 6637.40 | Train/Valid Acc.: 98.65%/96.80%
# 178/200 | Cost: 6628.72 | Train/Valid Acc.: 98.66%/96.80%
# 179/200 | Cost: 6583.52 | Train/Valid Acc.: 98.66%/96.78%
# 180/200 | Cost: 6545.47 | Train/Valid Acc.: 98.69%/96.78%
# 181/200 | Cost: 6521.63 | Train/Valid Acc.: 98.68%/96.82%
# 182/200 | Cost: 6497.40 | Train/Valid Acc.: 98.70%/96.84%
# 183/200 | Cost: 6451.61 | Train/Valid Acc.: 98.71%/96.84%
# 184/200 | Cost: 6431.38 | Train/Valid Acc.: 98.70%/96.82%
# 185/200 | Cost: 6401.31 | Train/Valid Acc.: 98.71%/96.84%
# 186/200 | Cost: 6372.37 | Train/Valid Acc.: 98.75%/96.80%
# 187/200 | Cost: 6331.18 | Train/Valid Acc.: 98.75%/96.88%
# 188/200 | Cost: 6308.39 | Train/Valid Acc.: 98.74%/96.80%
# 189/200 | Cost: 6275.67 | Train/Valid Acc.: 98.76%/96.88%
# 190/200 | Cost: 6245.49 | Train/Valid Acc.: 98.79%/96.86%
# 191/200 | Cost: 6226.94 | Train/Valid Acc.: 98.79%/96.88%
# 192/200 | Cost: 6200.39 | Train/Valid Acc.: 98.78%/96.90%
# 193/200 | Cost: 6163.24 | Train/Valid Acc.: 98.80%/96.90%
# 194/200 | Cost: 6134.10 | Train/Valid Acc.: 98.79%/96.86%
# 195/200 | Cost: 6110.74 | Train/Valid Acc.: 98.81%/96.92%
# 196/200 | Cost: 6085.79 | Train/Valid Acc.: 98.82%/96.94%
# 197/200 | Cost: 6056.22 | Train/Valid Acc.: 98.82%/96.88%
# 198/200 | Cost: 6029.54 | Train/Valid Acc.: 98.84%/96.92%
# 199/200 | Cost: 6000.64 | Train/Valid Acc.: 98.84%/96.92%
# 200/200 | Cost: 5970.12 | Train/Valid Acc.: 98.84%/96.94%
# Test accuracy: 97.37%
# Train accuracy: 98.84%
# Val accuracy: 96.94%
# ===================================l2: 1================================
# 001/200 | Cost: 94032.04 | Train/Valid Acc.: 79.15%/79.20%
# 002/200 | Cost: 73706.29 | Train/Valid Acc.: 84.92%/84.70%
# 003/200 | Cost: 66452.71 | Train/Valid Acc.: 86.62%/86.22%
# 004/200 | Cost: 62970.65 | Train/Valid Acc.: 87.48%/87.20%
# 005/200 | Cost: 60992.76 | Train/Valid Acc.: 88.06%/87.96%
# 006/200 | Cost: 59848.12 | Train/Valid Acc.: 87.95%/87.66%
# 007/200 | Cost: 59074.81 | Train/Valid Acc.: 88.24%/87.78%
# 008/200 | Cost: 58488.47 | Train/Valid Acc.: 88.35%/88.30%
# 009/200 | Cost: 58237.09 | Train/Valid Acc.: 88.46%/88.12%
# 010/200 | Cost: 58033.20 | Train/Valid Acc.: 88.61%/88.36%
# 011/200 | Cost: 57760.97 | Train/Valid Acc.: 88.71%/88.56%
# 012/200 | Cost: 57512.25 | Train/Valid Acc.: 88.68%/88.32%
# 013/200 | Cost: 57415.64 | Train/Valid Acc.: 88.81%/88.64%
# 014/200 | Cost: 57307.39 | Train/Valid Acc.: 88.58%/88.10%
# 015/200 | Cost: 57078.70 | Train/Valid Acc.: 88.79%/88.50%
# 016/200 | Cost: 57053.58 | Train/Valid Acc.: 88.75%/88.34%
# 017/200 | Cost: 56972.60 | Train/Valid Acc.: 88.67%/88.36%
# 018/200 | Cost: 56875.77 | Train/Valid Acc.: 88.75%/88.42%
# 019/200 | Cost: 56891.05 | Train/Valid Acc.: 88.57%/88.20%
# 020/200 | Cost: 56767.11 | Train/Valid Acc.: 88.73%/88.20%
# 021/200 | Cost: 56706.65 | Train/Valid Acc.: 88.94%/88.72%
# 022/200 | Cost: 56682.54 | Train/Valid Acc.: 88.84%/88.54%
# 023/200 | Cost: 56575.52 | Train/Valid Acc.: 88.79%/88.46%
# 024/200 | Cost: 56638.29 | Train/Valid Acc.: 88.91%/88.52%
# 025/200 | Cost: 56540.31 | Train/Valid Acc.: 88.85%/88.46%
# 026/200 | Cost: 56539.25 | Train/Valid Acc.: 88.92%/88.42%
# 027/200 | Cost: 56472.16 | Train/Valid Acc.: 88.78%/88.40%
# 028/200 | Cost: 56459.78 | Train/Valid Acc.: 88.96%/88.60%
# 029/200 | Cost: 56419.28 | Train/Valid Acc.: 88.77%/88.42%
# 030/200 | Cost: 56392.96 | Train/Valid Acc.: 88.87%/88.56%
# 031/200 | Cost: 56480.58 | Train/Valid Acc.: 88.91%/88.66%
# 032/200 | Cost: 56364.36 | Train/Valid Acc.: 88.86%/88.82%
# 033/200 | Cost: 56328.76 | Train/Valid Acc.: 88.84%/88.52%
# 034/200 | Cost: 56347.17 | Train/Valid Acc.: 88.75%/88.28%
# 035/200 | Cost: 56293.59 | Train/Valid Acc.: 88.85%/88.32%
# 036/200 | Cost: 56344.46 | Train/Valid Acc.: 89.01%/88.82%
# 037/200 | Cost: 56311.47 | Train/Valid Acc.: 88.95%/88.70%
# 038/200 | Cost: 56227.36 | Train/Valid Acc.: 88.86%/88.42%
# 039/200 | Cost: 56257.12 | Train/Valid Acc.: 88.81%/88.58%
# 040/200 | Cost: 56209.87 | Train/Valid Acc.: 88.97%/88.72%
# 041/200 | Cost: 56220.98 | Train/Valid Acc.: 89.00%/88.74%
# 042/200 | Cost: 56230.41 | Train/Valid Acc.: 88.80%/88.38%
# 043/200 | Cost: 56229.00 | Train/Valid Acc.: 88.79%/88.28%
# 044/200 | Cost: 56188.84 | Train/Valid Acc.: 88.81%/88.50%
# 045/200 | Cost: 56194.89 | Train/Valid Acc.: 89.03%/88.92%
# 046/200 | Cost: 56169.70 | Train/Valid Acc.: 88.82%/88.66%
# 047/200 | Cost: 56148.97 | Train/Valid Acc.: 88.88%/88.64%
# 048/200 | Cost: 56186.42 | Train/Valid Acc.: 88.76%/88.38%
# 049/200 | Cost: 56155.38 | Train/Valid Acc.: 88.74%/88.34%
# 050/200 | Cost: 56095.26 | Train/Valid Acc.: 88.83%/88.46%
# 051/200 | Cost: 56128.54 | Train/Valid Acc.: 88.81%/88.48%
# 052/200 | Cost: 56084.13 | Train/Valid Acc.: 88.95%/88.56%
# 053/200 | Cost: 56118.63 | Train/Valid Acc.: 88.86%/88.60%
# 054/200 | Cost: 56132.90 | Train/Valid Acc.: 88.90%/88.62%
# 055/200 | Cost: 56079.27 | Train/Valid Acc.: 88.88%/88.58%
# 056/200 | Cost: 56105.11 | Train/Valid Acc.: 88.62%/88.26%
# 057/200 | Cost: 56044.89 | Train/Valid Acc.: 88.89%/88.40%
# 058/200 | Cost: 56063.25 | Train/Valid Acc.: 88.81%/88.46%
# 059/200 | Cost: 56128.30 | Train/Valid Acc.: 88.87%/88.46%
# 060/200 | Cost: 56013.43 | Train/Valid Acc.: 88.90%/88.58%
# 061/200 | Cost: 56123.00 | Train/Valid Acc.: 88.74%/88.38%
# 062/200 | Cost: 56017.80 | Train/Valid Acc.: 88.79%/88.36%
# 063/200 | Cost: 56041.46 | Train/Valid Acc.: 88.91%/88.50%
# 064/200 | Cost: 56123.50 | Train/Valid Acc.: 88.90%/88.58%
# 065/200 | Cost: 56076.30 | Train/Valid Acc.: 88.71%/88.52%
# 066/200 | Cost: 56087.68 | Train/Valid Acc.: 88.76%/88.70%
# 067/200 | Cost: 56000.09 | Train/Valid Acc.: 88.90%/88.64%
# 068/200 | Cost: 55992.87 | Train/Valid Acc.: 88.92%/88.70%
# 069/200 | Cost: 56020.94 | Train/Valid Acc.: 88.80%/88.46%
# 070/200 | Cost: 55959.46 | Train/Valid Acc.: 88.96%/88.66%
# 071/200 | Cost: 56026.48 | Train/Valid Acc.: 88.70%/88.44%
# 072/200 | Cost: 56018.03 | Train/Valid Acc.: 88.80%/88.62%
# 073/200 | Cost: 56066.91 | Train/Valid Acc.: 88.74%/88.62%
# 074/200 | Cost: 56039.88 | Train/Valid Acc.: 88.78%/88.78%
# 075/200 | Cost: 55959.28 | Train/Valid Acc.: 88.86%/88.70%
# 076/200 | Cost: 56230.40 | Train/Valid Acc.: 88.62%/88.50%
# 077/200 | Cost: 56025.57 | Train/Valid Acc.: 88.90%/88.72%
# 078/200 | Cost: 56052.35 | Train/Valid Acc.: 88.74%/88.28%
# 079/200 | Cost: 55997.70 | Train/Valid Acc.: 88.75%/88.44%
# 080/200 | Cost: 55970.30 | Train/Valid Acc.: 88.78%/88.36%
# 081/200 | Cost: 56097.95 | Train/Valid Acc.: 88.87%/88.84%
# 082/200 | Cost: 56010.70 | Train/Valid Acc.: 88.61%/88.18%
# 083/200 | Cost: 56013.70 | Train/Valid Acc.: 88.84%/88.64%
# 084/200 | Cost: 56035.26 | Train/Valid Acc.: 88.68%/88.10%
# 085/200 | Cost: 56024.03 | Train/Valid Acc.: 88.78%/88.38%
# 086/200 | Cost: 56024.02 | Train/Valid Acc.: 88.83%/88.38%
# 087/200 | Cost: 56045.20 | Train/Valid Acc.: 88.75%/88.46%
# 088/200 | Cost: 55988.75 | Train/Valid Acc.: 88.71%/88.38%
# 089/200 | Cost: 55969.77 | Train/Valid Acc.: 88.77%/88.40%
# 090/200 | Cost: 55941.96 | Train/Valid Acc.: 88.85%/88.58%
# 091/200 | Cost: 55955.03 | Train/Valid Acc.: 88.85%/88.60%
# 092/200 | Cost: 56032.69 | Train/Valid Acc.: 88.73%/88.40%
# 093/200 | Cost: 55953.89 | Train/Valid Acc.: 88.88%/88.62%
# 094/200 | Cost: 56002.58 | Train/Valid Acc.: 88.78%/88.54%
# 095/200 | Cost: 55948.20 | Train/Valid Acc.: 88.90%/88.60%
# 096/200 | Cost: 55940.21 | Train/Valid Acc.: 88.85%/88.72%
# 097/200 | Cost: 55935.52 | Train/Valid Acc.: 88.93%/88.80%
# 098/200 | Cost: 55934.58 | Train/Valid Acc.: 88.89%/88.66%
# 099/200 | Cost: 56109.67 | Train/Valid Acc.: 88.48%/87.84%
# 100/200 | Cost: 55981.37 | Train/Valid Acc.: 88.81%/88.62%
# 101/200 | Cost: 55933.34 | Train/Valid Acc.: 88.83%/88.50%
# 102/200 | Cost: 56001.76 | Train/Valid Acc.: 88.71%/88.30%
# 103/200 | Cost: 55972.22 | Train/Valid Acc.: 88.74%/88.38%
# 104/200 | Cost: 55931.61 | Train/Valid Acc.: 88.86%/88.48%
# 105/200 | Cost: 56010.41 | Train/Valid Acc.: 88.89%/88.60%
# 106/200 | Cost: 56010.62 | Train/Valid Acc.: 88.62%/88.34%
# 107/200 | Cost: 56120.00 | Train/Valid Acc.: 88.65%/88.36%
# 108/200 | Cost: 55968.14 | Train/Valid Acc.: 88.89%/88.70%
# 109/200 | Cost: 55969.61 | Train/Valid Acc.: 88.89%/88.76%
# 110/200 | Cost: 55931.19 | Train/Valid Acc.: 88.84%/88.78%
# 111/200 | Cost: 55917.28 | Train/Valid Acc.: 88.75%/88.44%
# 112/200 | Cost: 55975.56 | Train/Valid Acc.: 88.96%/88.84%
# 113/200 | Cost: 55987.86 | Train/Valid Acc.: 88.85%/88.76%
# 114/200 | Cost: 55948.24 | Train/Valid Acc.: 88.85%/88.74%
# 115/200 | Cost: 55920.71 | Train/Valid Acc.: 88.82%/88.66%
# 116/200 | Cost: 56000.37 | Train/Valid Acc.: 88.80%/88.26%
# 117/200 | Cost: 56016.88 | Train/Valid Acc.: 88.64%/88.40%
# 118/200 | Cost: 55947.31 | Train/Valid Acc.: 88.95%/88.68%
# 119/200 | Cost: 55972.25 | Train/Valid Acc.: 88.93%/88.96%
# 120/200 | Cost: 55936.49 | Train/Valid Acc.: 88.77%/88.58%
# 121/200 | Cost: 55913.63 | Train/Valid Acc.: 88.75%/88.44%
# 122/200 | Cost: 55946.48 | Train/Valid Acc.: 88.84%/88.66%
# 123/200 | Cost: 55910.32 | Train/Valid Acc.: 88.71%/88.38%
# 124/200 | Cost: 55967.40 | Train/Valid Acc.: 88.83%/88.42%
# 125/200 | Cost: 55929.52 | Train/Valid Acc.: 88.82%/88.54%
# 126/200 | Cost: 55898.61 | Train/Valid Acc.: 88.90%/88.78%
# 127/200 | Cost: 56114.04 | Train/Valid Acc.: 88.68%/88.50%
# 128/200 | Cost: 55935.51 | Train/Valid Acc.: 88.77%/88.56%
# 129/200 | Cost: 56010.49 | Train/Valid Acc.: 88.76%/88.68%
# 130/200 | Cost: 55915.66 | Train/Valid Acc.: 88.79%/88.50%
# 131/200 | Cost: 55903.02 | Train/Valid Acc.: 88.76%/88.44%
# 132/200 | Cost: 55915.62 | Train/Valid Acc.: 88.85%/88.62%
# 133/200 | Cost: 55965.91 | Train/Valid Acc.: 88.78%/88.64%
# 134/200 | Cost: 55931.67 | Train/Valid Acc.: 88.70%/88.60%
# 135/200 | Cost: 55894.96 | Train/Valid Acc.: 88.86%/88.60%
# 136/200 | Cost: 56054.22 | Train/Valid Acc.: 88.79%/88.74%
# 137/200 | Cost: 55984.45 | Train/Valid Acc.: 88.65%/88.46%
# 138/200 | Cost: 55858.89 | Train/Valid Acc.: 88.88%/88.66%
# 139/200 | Cost: 55873.66 | Train/Valid Acc.: 88.86%/88.52%
# 140/200 | Cost: 55928.28 | Train/Valid Acc.: 88.81%/88.48%
# 141/200 | Cost: 55886.15 | Train/Valid Acc.: 88.85%/88.66%
# 142/200 | Cost: 55917.61 | Train/Valid Acc.: 88.76%/88.28%
# 143/200 | Cost: 55913.37 | Train/Valid Acc.: 88.80%/88.46%
# 144/200 | Cost: 55976.77 | Train/Valid Acc.: 88.75%/88.32%
# 145/200 | Cost: 55928.11 | Train/Valid Acc.: 88.82%/88.52%
# 146/200 | Cost: 56005.29 | Train/Valid Acc.: 88.77%/88.50%
# 147/200 | Cost: 55910.70 | Train/Valid Acc.: 88.73%/88.30%
# 148/200 | Cost: 55957.67 | Train/Valid Acc.: 88.79%/88.50%
# 149/200 | Cost: 55972.25 | Train/Valid Acc.: 88.79%/88.72%
# 150/200 | Cost: 56034.29 | Train/Valid Acc.: 88.66%/88.18%
# 151/200 | Cost: 55907.93 | Train/Valid Acc.: 88.78%/88.54%
# 152/200 | Cost: 55883.62 | Train/Valid Acc.: 88.76%/88.26%
# 153/200 | Cost: 55824.76 | Train/Valid Acc.: 88.83%/88.46%
# 154/200 | Cost: 55888.76 | Train/Valid Acc.: 88.94%/88.82%
# 155/200 | Cost: 55916.35 | Train/Valid Acc.: 88.88%/88.70%
# 156/200 | Cost: 55947.04 | Train/Valid Acc.: 88.78%/88.28%
# 157/200 | Cost: 55885.61 | Train/Valid Acc.: 88.76%/88.52%
# 158/200 | Cost: 55896.32 | Train/Valid Acc.: 88.83%/88.56%
# 159/200 | Cost: 55954.86 | Train/Valid Acc.: 88.74%/88.54%
# 160/200 | Cost: 55883.01 | Train/Valid Acc.: 88.87%/88.64%
# 161/200 | Cost: 55857.14 | Train/Valid Acc.: 88.75%/88.46%
# 162/200 | Cost: 55865.67 | Train/Valid Acc.: 88.85%/88.64%
# 163/200 | Cost: 55857.90 | Train/Valid Acc.: 89.01%/88.86%
# 164/200 | Cost: 55871.07 | Train/Valid Acc.: 88.97%/88.96%
# 165/200 | Cost: 55902.53 | Train/Valid Acc.: 88.69%/88.40%
# 166/200 | Cost: 55920.62 | Train/Valid Acc.: 88.73%/88.60%
# 167/200 | Cost: 55877.78 | Train/Valid Acc.: 88.82%/88.62%
# 168/200 | Cost: 55827.31 | Train/Valid Acc.: 88.77%/88.34%
# 169/200 | Cost: 55857.12 | Train/Valid Acc.: 88.81%/88.46%
# 170/200 | Cost: 55871.73 | Train/Valid Acc.: 88.69%/88.36%
# 171/200 | Cost: 55912.28 | Train/Valid Acc.: 88.96%/88.86%
# 172/200 | Cost: 55833.59 | Train/Valid Acc.: 88.97%/88.88%
# 173/200 | Cost: 55915.12 | Train/Valid Acc.: 88.87%/88.58%
# 174/200 | Cost: 55864.32 | Train/Valid Acc.: 88.84%/88.44%
# 175/200 | Cost: 55966.40 | Train/Valid Acc.: 88.60%/88.42%
# 176/200 | Cost: 55864.72 | Train/Valid Acc.: 88.72%/88.42%
# 177/200 | Cost: 55894.45 | Train/Valid Acc.: 88.96%/88.62%
# 178/200 | Cost: 55854.77 | Train/Valid Acc.: 88.81%/88.50%
# 179/200 | Cost: 55885.39 | Train/Valid Acc.: 88.80%/88.34%
# 180/200 | Cost: 55851.76 | Train/Valid Acc.: 88.86%/88.70%
# 181/200 | Cost: 55901.36 | Train/Valid Acc.: 88.68%/88.32%
# 182/200 | Cost: 55912.79 | Train/Valid Acc.: 88.66%/88.38%
# 183/200 | Cost: 55865.95 | Train/Valid Acc.: 88.85%/88.66%
# 184/200 | Cost: 55874.90 | Train/Valid Acc.: 88.92%/88.82%
# 185/200 | Cost: 55830.94 | Train/Valid Acc.: 88.78%/88.52%
# 186/200 | Cost: 55838.49 | Train/Valid Acc.: 88.77%/88.56%
# 187/200 | Cost: 55883.08 | Train/Valid Acc.: 88.84%/88.88%
# 188/200 | Cost: 55914.69 | Train/Valid Acc.: 88.68%/88.30%
# 189/200 | Cost: 55819.34 | Train/Valid Acc.: 88.88%/88.60%
# 190/200 | Cost: 55831.12 | Train/Valid Acc.: 88.75%/88.62%
# 191/200 | Cost: 55870.12 | Train/Valid Acc.: 88.70%/88.50%
# 192/200 | Cost: 55815.63 | Train/Valid Acc.: 88.84%/88.78%
# 193/200 | Cost: 55948.71 | Train/Valid Acc.: 88.72%/88.62%
# 194/200 | Cost: 55862.59 | Train/Valid Acc.: 88.83%/88.84%
# 195/200 | Cost: 55841.22 | Train/Valid Acc.: 88.80%/88.60%
# 196/200 | Cost: 55857.68 | Train/Valid Acc.: 88.78%/88.38%
# 197/200 | Cost: 55869.37 | Train/Valid Acc.: 88.88%/88.70%
# 198/200 | Cost: 55919.67 | Train/Valid Acc.: 88.86%/88.76%
# 199/200 | Cost: 55869.99 | Train/Valid Acc.: 88.88%/88.60%
# 200/200 | Cost: 55875.04 | Train/Valid Acc.: 88.82%/88.72%
# Test accuracy: 89.24%
# Train accuracy: 88.82%
# Val accuracy: 88.72%
# ===================================l2: 2================================
# 001/200 | Cost: 104366.12 | Train/Valid Acc.: 77.00%/76.70%
# 002/200 | Cost: 87514.22 | Train/Valid Acc.: 82.61%/82.42%
# 003/200 | Cost: 82538.54 | Train/Valid Acc.: 84.32%/84.10%
# 004/200 | Cost: 80549.97 | Train/Valid Acc.: 85.13%/84.92%
# 005/200 | Cost: 79447.24 | Train/Valid Acc.: 85.86%/85.88%
# 006/200 | Cost: 78831.56 | Train/Valid Acc.: 85.15%/84.84%
# 007/200 | Cost: 78380.17 | Train/Valid Acc.: 85.73%/85.82%
# 008/200 | Cost: 77941.56 | Train/Valid Acc.: 85.86%/85.96%
# 009/200 | Cost: 77862.90 | Train/Valid Acc.: 85.52%/85.24%
# 010/200 | Cost: 77728.46 | Train/Valid Acc.: 86.23%/86.18%
# 011/200 | Cost: 77497.47 | Train/Valid Acc.: 86.58%/86.46%
# 012/200 | Cost: 77276.03 | Train/Valid Acc.: 86.29%/86.06%
# 013/200 | Cost: 77264.12 | Train/Valid Acc.: 86.44%/86.54%
# 014/200 | Cost: 77136.92 | Train/Valid Acc.: 85.36%/85.42%
# 015/200 | Cost: 76886.43 | Train/Valid Acc.: 86.06%/85.96%
# 016/200 | Cost: 76915.23 | Train/Valid Acc.: 86.27%/86.18%
# 017/200 | Cost: 76812.80 | Train/Valid Acc.: 86.05%/86.04%
# 018/200 | Cost: 76741.95 | Train/Valid Acc.: 86.10%/86.24%
# 019/200 | Cost: 76776.24 | Train/Valid Acc.: 85.50%/85.44%
# 020/200 | Cost: 76643.68 | Train/Valid Acc.: 86.07%/85.88%
# 021/200 | Cost: 76588.89 | Train/Valid Acc.: 86.45%/86.48%
# 022/200 | Cost: 76582.26 | Train/Valid Acc.: 86.10%/85.88%
# 023/200 | Cost: 76426.96 | Train/Valid Acc.: 86.14%/86.14%
# 024/200 | Cost: 76523.44 | Train/Valid Acc.: 86.55%/86.74%
# 025/200 | Cost: 76447.69 | Train/Valid Acc.: 86.31%/86.34%
# 026/200 | Cost: 76453.20 | Train/Valid Acc.: 86.29%/86.16%
# 027/200 | Cost: 76362.75 | Train/Valid Acc.: 86.05%/86.24%
# 028/200 | Cost: 76384.79 | Train/Valid Acc.: 86.37%/86.34%
# 029/200 | Cost: 76319.44 | Train/Valid Acc.: 86.35%/86.34%
# 030/200 | Cost: 76313.92 | Train/Valid Acc.: 86.27%/86.50%
# 031/200 | Cost: 76383.21 | Train/Valid Acc.: 86.19%/86.64%
# 032/200 | Cost: 76322.13 | Train/Valid Acc.: 86.12%/86.40%
# 033/200 | Cost: 76273.76 | Train/Valid Acc.: 85.90%/85.90%
# 034/200 | Cost: 76228.73 | Train/Valid Acc.: 85.93%/85.88%
# 035/200 | Cost: 76194.86 | Train/Valid Acc.: 86.30%/86.30%
# 036/200 | Cost: 76236.54 | Train/Valid Acc.: 86.71%/86.98%
# 037/200 | Cost: 76185.78 | Train/Valid Acc.: 86.55%/86.42%
# 038/200 | Cost: 76116.20 | Train/Valid Acc.: 86.23%/86.34%
# 039/200 | Cost: 76167.13 | Train/Valid Acc.: 86.09%/86.26%
# 040/200 | Cost: 76110.19 | Train/Valid Acc.: 86.38%/86.34%
# 041/200 | Cost: 76120.61 | Train/Valid Acc.: 86.23%/86.46%
# 042/200 | Cost: 76131.89 | Train/Valid Acc.: 86.35%/86.24%
# 043/200 | Cost: 76177.40 | Train/Valid Acc.: 86.01%/86.30%
# 044/200 | Cost: 76058.61 | Train/Valid Acc.: 86.29%/86.34%
# 045/200 | Cost: 76081.72 | Train/Valid Acc.: 86.75%/87.02%
# 046/200 | Cost: 76056.46 | Train/Valid Acc.: 86.05%/86.36%
# 047/200 | Cost: 76006.51 | Train/Valid Acc.: 86.39%/86.62%
# 048/200 | Cost: 76077.08 | Train/Valid Acc.: 86.20%/86.16%
# 049/200 | Cost: 76011.41 | Train/Valid Acc.: 86.13%/86.24%
# 050/200 | Cost: 75977.56 | Train/Valid Acc.: 86.07%/86.30%
# 051/200 | Cost: 75976.28 | Train/Valid Acc.: 85.85%/85.80%
# 052/200 | Cost: 75956.98 | Train/Valid Acc.: 86.30%/86.40%
# 053/200 | Cost: 76003.29 | Train/Valid Acc.: 86.17%/86.46%
# 054/200 | Cost: 75984.54 | Train/Valid Acc.: 86.62%/86.70%
# 055/200 | Cost: 75925.76 | Train/Valid Acc.: 86.40%/86.58%
# 056/200 | Cost: 75953.63 | Train/Valid Acc.: 86.05%/86.28%
# 057/200 | Cost: 75893.55 | Train/Valid Acc.: 86.47%/86.40%
# 058/200 | Cost: 75900.58 | Train/Valid Acc.: 86.38%/86.64%
# 059/200 | Cost: 75985.16 | Train/Valid Acc.: 86.33%/86.42%
# 060/200 | Cost: 75841.95 | Train/Valid Acc.: 86.49%/86.66%
# 061/200 | Cost: 75995.74 | Train/Valid Acc.: 85.96%/85.88%
# 062/200 | Cost: 75822.30 | Train/Valid Acc.: 86.34%/86.52%
# 063/200 | Cost: 75901.56 | Train/Valid Acc.: 86.25%/86.16%
# 064/200 | Cost: 75971.73 | Train/Valid Acc.: 86.57%/86.62%
# 065/200 | Cost: 75919.03 | Train/Valid Acc.: 86.20%/86.50%
# 066/200 | Cost: 75903.51 | Train/Valid Acc.: 86.05%/86.26%
# 067/200 | Cost: 75816.86 | Train/Valid Acc.: 86.56%/86.66%
# 068/200 | Cost: 75812.85 | Train/Valid Acc.: 86.35%/86.36%
# 069/200 | Cost: 75847.80 | Train/Valid Acc.: 86.41%/86.50%
# 070/200 | Cost: 75743.55 | Train/Valid Acc.: 86.51%/86.76%
# 071/200 | Cost: 75801.06 | Train/Valid Acc.: 85.81%/86.10%
# 072/200 | Cost: 75845.55 | Train/Valid Acc.: 86.59%/86.86%
# 073/200 | Cost: 75902.80 | Train/Valid Acc.: 86.13%/86.48%
# 074/200 | Cost: 75815.09 | Train/Valid Acc.: 86.28%/86.64%
# 075/200 | Cost: 75761.96 | Train/Valid Acc.: 86.19%/86.34%
# 076/200 | Cost: 76121.72 | Train/Valid Acc.: 86.11%/86.22%
# 077/200 | Cost: 75874.81 | Train/Valid Acc.: 86.23%/86.52%
# 078/200 | Cost: 75896.63 | Train/Valid Acc.: 86.13%/86.20%
# 079/200 | Cost: 75775.64 | Train/Valid Acc.: 86.03%/86.38%
# 080/200 | Cost: 75769.97 | Train/Valid Acc.: 86.11%/86.30%
# 081/200 | Cost: 75879.29 | Train/Valid Acc.: 86.45%/86.76%
# 082/200 | Cost: 75838.81 | Train/Valid Acc.: 85.83%/85.74%
# 083/200 | Cost: 75839.95 | Train/Valid Acc.: 86.07%/86.32%
# 084/200 | Cost: 75792.40 | Train/Valid Acc.: 86.07%/86.16%
# 085/200 | Cost: 75812.12 | Train/Valid Acc.: 85.74%/85.92%
# 086/200 | Cost: 75819.69 | Train/Valid Acc.: 85.94%/86.04%
# 087/200 | Cost: 75857.27 | Train/Valid Acc.: 86.36%/86.42%
# 088/200 | Cost: 75797.38 | Train/Valid Acc.: 86.05%/86.22%
# 089/200 | Cost: 75736.31 | Train/Valid Acc.: 86.31%/86.50%
# 090/200 | Cost: 75734.76 | Train/Valid Acc.: 86.56%/86.88%
# 091/200 | Cost: 75713.08 | Train/Valid Acc.: 86.13%/86.20%
# 092/200 | Cost: 75859.50 | Train/Valid Acc.: 86.30%/86.38%
# 093/200 | Cost: 75736.37 | Train/Valid Acc.: 86.27%/86.50%
# 094/200 | Cost: 75784.22 | Train/Valid Acc.: 86.35%/86.62%
# 095/200 | Cost: 75741.03 | Train/Valid Acc.: 86.55%/86.82%
# 096/200 | Cost: 75718.60 | Train/Valid Acc.: 86.25%/86.38%
# 097/200 | Cost: 75716.75 | Train/Valid Acc.: 86.20%/86.68%
# 098/200 | Cost: 75720.56 | Train/Valid Acc.: 86.42%/86.36%
# 099/200 | Cost: 75926.82 | Train/Valid Acc.: 85.35%/85.10%
# 100/200 | Cost: 75765.11 | Train/Valid Acc.: 86.24%/86.62%
# 101/200 | Cost: 75690.17 | Train/Valid Acc.: 86.16%/86.28%
# 102/200 | Cost: 75768.31 | Train/Valid Acc.: 85.98%/86.10%
# 103/200 | Cost: 75723.23 | Train/Valid Acc.: 86.20%/86.22%
# 104/200 | Cost: 75711.03 | Train/Valid Acc.: 86.52%/86.74%
# 105/200 | Cost: 75864.04 | Train/Valid Acc.: 86.57%/86.82%
# 106/200 | Cost: 75797.49 | Train/Valid Acc.: 86.04%/86.22%
# 107/200 | Cost: 75927.02 | Train/Valid Acc.: 85.97%/86.32%
# 108/200 | Cost: 75746.71 | Train/Valid Acc.: 86.28%/86.62%
# 109/200 | Cost: 75807.91 | Train/Valid Acc.: 86.37%/86.70%
# 110/200 | Cost: 75682.16 | Train/Valid Acc.: 86.28%/86.64%
# 111/200 | Cost: 75677.94 | Train/Valid Acc.: 86.23%/86.48%
# 112/200 | Cost: 75751.58 | Train/Valid Acc.: 86.64%/86.80%
# 113/200 | Cost: 75780.47 | Train/Valid Acc.: 86.13%/86.66%
# 114/200 | Cost: 75705.21 | Train/Valid Acc.: 86.30%/86.80%
# 115/200 | Cost: 75685.40 | Train/Valid Acc.: 86.30%/86.42%
# 116/200 | Cost: 75780.76 | Train/Valid Acc.: 86.31%/86.34%
# 117/200 | Cost: 75808.54 | Train/Valid Acc.: 85.98%/86.12%
# 118/200 | Cost: 75701.08 | Train/Valid Acc.: 86.66%/86.98%
# 119/200 | Cost: 75723.49 | Train/Valid Acc.: 86.11%/86.48%
# 120/200 | Cost: 75704.08 | Train/Valid Acc.: 86.16%/86.34%
# 121/200 | Cost: 75662.88 | Train/Valid Acc.: 86.27%/86.70%
# 122/200 | Cost: 75708.51 | Train/Valid Acc.: 86.00%/86.48%
# 123/200 | Cost: 75667.47 | Train/Valid Acc.: 85.89%/85.92%
# 124/200 | Cost: 75757.60 | Train/Valid Acc.: 86.34%/86.68%
# 125/200 | Cost: 75739.94 | Train/Valid Acc.: 86.22%/86.36%
# 126/200 | Cost: 75640.72 | Train/Valid Acc.: 86.58%/86.88%
# 127/200 | Cost: 75847.05 | Train/Valid Acc.: 85.61%/86.14%
# 128/200 | Cost: 75690.45 | Train/Valid Acc.: 85.68%/85.98%
# 129/200 | Cost: 75754.43 | Train/Valid Acc.: 86.18%/86.34%
# 130/200 | Cost: 75653.66 | Train/Valid Acc.: 85.95%/86.24%
# 131/200 | Cost: 75684.54 | Train/Valid Acc.: 85.93%/86.14%
# 132/200 | Cost: 75702.60 | Train/Valid Acc.: 86.37%/86.54%
# 133/200 | Cost: 75736.34 | Train/Valid Acc.: 86.03%/85.92%
# 134/200 | Cost: 75719.37 | Train/Valid Acc.: 86.14%/86.04%
# 135/200 | Cost: 75662.12 | Train/Valid Acc.: 86.51%/86.80%
# 136/200 | Cost: 75820.65 | Train/Valid Acc.: 85.84%/86.24%
# 137/200 | Cost: 75720.52 | Train/Valid Acc.: 86.27%/86.62%
# 138/200 | Cost: 75589.18 | Train/Valid Acc.: 86.17%/86.34%
# 139/200 | Cost: 75627.27 | Train/Valid Acc.: 86.49%/86.70%
# 140/200 | Cost: 75720.59 | Train/Valid Acc.: 85.97%/86.14%
# 141/200 | Cost: 75666.21 | Train/Valid Acc.: 86.44%/86.58%
# 142/200 | Cost: 75663.82 | Train/Valid Acc.: 86.22%/86.40%
# 143/200 | Cost: 75692.69 | Train/Valid Acc.: 86.32%/86.32%
# 144/200 | Cost: 75766.20 | Train/Valid Acc.: 85.91%/85.86%
# 145/200 | Cost: 75740.29 | Train/Valid Acc.: 86.40%/86.44%
# 146/200 | Cost: 75786.92 | Train/Valid Acc.: 85.57%/85.62%
# 147/200 | Cost: 75674.73 | Train/Valid Acc.: 86.15%/86.18%
# 148/200 | Cost: 75752.15 | Train/Valid Acc.: 86.43%/86.24%
# 149/200 | Cost: 75755.21 | Train/Valid Acc.: 86.29%/86.82%
# 150/200 | Cost: 75838.38 | Train/Valid Acc.: 86.02%/86.24%
# 151/200 | Cost: 75664.84 | Train/Valid Acc.: 86.36%/86.38%
# 152/200 | Cost: 75588.65 | Train/Valid Acc.: 86.32%/86.52%
# 153/200 | Cost: 75545.40 | Train/Valid Acc.: 86.12%/86.32%
# 154/200 | Cost: 75659.14 | Train/Valid Acc.: 86.42%/86.60%
# 155/200 | Cost: 75702.37 | Train/Valid Acc.: 86.16%/86.64%
# 156/200 | Cost: 75755.13 | Train/Valid Acc.: 86.03%/86.18%
# 157/200 | Cost: 75645.24 | Train/Valid Acc.: 86.02%/86.26%
# 158/200 | Cost: 75706.07 | Train/Valid Acc.: 86.43%/86.48%
# 159/200 | Cost: 75771.32 | Train/Valid Acc.: 86.30%/86.36%
# 160/200 | Cost: 75671.65 | Train/Valid Acc.: 86.48%/86.56%
# 161/200 | Cost: 75590.76 | Train/Valid Acc.: 85.95%/86.16%
# 162/200 | Cost: 75648.75 | Train/Valid Acc.: 86.31%/86.48%
# 163/200 | Cost: 75623.75 | Train/Valid Acc.: 86.51%/86.76%
# 164/200 | Cost: 75655.05 | Train/Valid Acc.: 86.38%/86.62%
# 165/200 | Cost: 75659.60 | Train/Valid Acc.: 86.27%/86.42%
# 166/200 | Cost: 75692.52 | Train/Valid Acc.: 86.04%/86.02%
# 167/200 | Cost: 75652.80 | Train/Valid Acc.: 86.16%/86.28%
# 168/200 | Cost: 75601.40 | Train/Valid Acc.: 86.09%/86.18%
# 169/200 | Cost: 75624.93 | Train/Valid Acc.: 86.11%/86.34%
# 170/200 | Cost: 75655.58 | Train/Valid Acc.: 85.95%/85.96%
# 171/200 | Cost: 75676.95 | Train/Valid Acc.: 86.70%/86.90%
# 172/200 | Cost: 75608.80 | Train/Valid Acc.: 86.53%/86.82%
# 173/200 | Cost: 75706.98 | Train/Valid Acc.: 85.98%/86.04%
# 174/200 | Cost: 75617.61 | Train/Valid Acc.: 86.33%/86.38%
# 175/200 | Cost: 75746.03 | Train/Valid Acc.: 85.71%/85.86%
# 176/200 | Cost: 75645.00 | Train/Valid Acc.: 86.24%/86.22%
# 177/200 | Cost: 75709.50 | Train/Valid Acc.: 86.55%/86.86%
# 178/200 | Cost: 75642.15 | Train/Valid Acc.: 86.05%/86.14%
# 179/200 | Cost: 75695.24 | Train/Valid Acc.: 86.31%/86.70%
# 180/200 | Cost: 75627.41 | Train/Valid Acc.: 86.21%/86.34%
# 181/200 | Cost: 75706.64 | Train/Valid Acc.: 85.59%/85.58%
# 182/200 | Cost: 75733.56 | Train/Valid Acc.: 85.95%/85.68%
# 183/200 | Cost: 75674.79 | Train/Valid Acc.: 85.91%/86.28%
# 184/200 | Cost: 75663.19 | Train/Valid Acc.: 86.53%/86.72%
# 185/200 | Cost: 75598.96 | Train/Valid Acc.: 85.89%/85.98%
# 186/200 | Cost: 75585.88 | Train/Valid Acc.: 86.25%/86.66%
# 187/200 | Cost: 75670.08 | Train/Valid Acc.: 86.31%/86.82%
# 188/200 | Cost: 75693.04 | Train/Valid Acc.: 86.15%/86.38%
# 189/200 | Cost: 75577.48 | Train/Valid Acc.: 86.53%/86.78%
# 190/200 | Cost: 75597.57 | Train/Valid Acc.: 86.21%/86.30%
# 191/200 | Cost: 75672.20 | Train/Valid Acc.: 85.95%/86.32%
# 192/200 | Cost: 75576.66 | Train/Valid Acc.: 86.18%/86.36%
# 193/200 | Cost: 75742.79 | Train/Valid Acc.: 86.12%/86.32%
# 194/200 | Cost: 75659.63 | Train/Valid Acc.: 86.20%/86.64%
# 195/200 | Cost: 75621.63 | Train/Valid Acc.: 85.91%/86.06%
# 196/200 | Cost: 75642.10 | Train/Valid Acc.: 86.15%/86.42%
# 197/200 | Cost: 75657.28 | Train/Valid Acc.: 86.09%/86.08%
# 198/200 | Cost: 75732.73 | Train/Valid Acc.: 86.51%/86.86%
# 199/200 | Cost: 75682.56 | Train/Valid Acc.: 86.38%/86.40%
# 200/200 | Cost: 75634.09 | Train/Valid Acc.: 86.26%/86.72%
# Test accuracy: 87.01%
# Train accuracy: 86.26%
# Val accuracy: 86.72%
# ===================================l2: 3================================
# 001/200 | Cost: 114450.07 | Train/Valid Acc.: 73.77%/73.84%
# 002/200 | Cost: 100686.64 | Train/Valid Acc.: 79.33%/79.16%
# 003/200 | Cost: 97041.93 | Train/Valid Acc.: 80.67%/80.36%
# 004/200 | Cost: 95697.71 | Train/Valid Acc.: 81.05%/80.68%
# 005/200 | Cost: 94967.49 | Train/Valid Acc.: 82.06%/81.84%
# 006/200 | Cost: 94582.25 | Train/Valid Acc.: 80.28%/79.78%
# 007/200 | Cost: 94331.38 | Train/Valid Acc.: 81.84%/81.76%
# 008/200 | Cost: 94001.84 | Train/Valid Acc.: 81.67%/81.70%
# 009/200 | Cost: 94048.22 | Train/Valid Acc.: 79.42%/78.44%
# 010/200 | Cost: 93955.90 | Train/Valid Acc.: 82.17%/81.94%
# 011/200 | Cost: 93769.67 | Train/Valid Acc.: 83.66%/83.06%
# 012/200 | Cost: 93588.67 | Train/Valid Acc.: 82.65%/82.04%
# 013/200 | Cost: 93653.91 | Train/Valid Acc.: 82.74%/82.66%
# 014/200 | Cost: 93489.54 | Train/Valid Acc.: 78.98%/79.08%
# 015/200 | Cost: 93243.44 | Train/Valid Acc.: 80.78%/80.70%
# 016/200 | Cost: 93315.07 | Train/Valid Acc.: 82.52%/82.34%
# 017/200 | Cost: 93186.56 | Train/Valid Acc.: 81.37%/81.00%
# 018/200 | Cost: 93144.31 | Train/Valid Acc.: 81.16%/81.12%
# 019/200 | Cost: 93179.97 | Train/Valid Acc.: 80.03%/79.98%
# 020/200 | Cost: 93046.19 | Train/Valid Acc.: 80.99%/80.66%
# 021/200 | Cost: 92993.62 | Train/Valid Acc.: 82.13%/81.86%
# 022/200 | Cost: 92970.67 | Train/Valid Acc.: 80.66%/80.32%
# 023/200 | Cost: 92792.46 | Train/Valid Acc.: 81.51%/81.00%
# 024/200 | Cost: 92918.84 | Train/Valid Acc.: 82.57%/82.82%
# 025/200 | Cost: 92857.08 | Train/Valid Acc.: 82.36%/82.06%
# 026/200 | Cost: 92863.51 | Train/Valid Acc.: 82.42%/82.20%
# 027/200 | Cost: 92755.12 | Train/Valid Acc.: 81.33%/81.18%
# 028/200 | Cost: 92790.15 | Train/Valid Acc.: 81.99%/81.76%
# 029/200 | Cost: 92712.20 | Train/Valid Acc.: 83.01%/82.60%
# 030/200 | Cost: 92721.61 | Train/Valid Acc.: 81.92%/81.70%
# 031/200 | Cost: 92759.22 | Train/Valid Acc.: 81.23%/80.94%
# 032/200 | Cost: 92742.92 | Train/Valid Acc.: 81.14%/81.20%
# 033/200 | Cost: 92667.09 | Train/Valid Acc.: 80.31%/80.18%
# 034/200 | Cost: 92588.17 | Train/Valid Acc.: 80.80%/80.40%
# 035/200 | Cost: 92589.67 | Train/Valid Acc.: 82.69%/82.20%
# 036/200 | Cost: 92612.41 | Train/Valid Acc.: 83.36%/83.14%
# 037/200 | Cost: 92545.17 | Train/Valid Acc.: 82.81%/82.62%
# 038/200 | Cost: 92485.37 | Train/Valid Acc.: 81.92%/81.62%
# 039/200 | Cost: 92566.14 | Train/Valid Acc.: 80.97%/81.02%
# 040/200 | Cost: 92504.43 | Train/Valid Acc.: 82.47%/82.02%
# 041/200 | Cost: 92488.16 | Train/Valid Acc.: 81.12%/80.80%
# 042/200 | Cost: 92531.00 | Train/Valid Acc.: 83.16%/82.34%
# 043/200 | Cost: 92592.62 | Train/Valid Acc.: 81.82%/81.92%
# 044/200 | Cost: 92422.54 | Train/Valid Acc.: 82.41%/82.02%
# 045/200 | Cost: 92460.36 | Train/Valid Acc.: 82.71%/82.62%
# 046/200 | Cost: 92427.02 | Train/Valid Acc.: 81.39%/81.34%
# 047/200 | Cost: 92363.65 | Train/Valid Acc.: 82.37%/82.26%
# 048/200 | Cost: 92459.62 | Train/Valid Acc.: 82.87%/81.98%
# 049/200 | Cost: 92371.83 | Train/Valid Acc.: 82.16%/82.06%
# 050/200 | Cost: 92373.91 | Train/Valid Acc.: 81.35%/80.84%
# 051/200 | Cost: 92333.15 | Train/Valid Acc.: 80.43%/80.24%
# 052/200 | Cost: 92327.69 | Train/Valid Acc.: 82.12%/81.78%
# 053/200 | Cost: 92390.34 | Train/Valid Acc.: 81.54%/81.54%
# 054/200 | Cost: 92335.41 | Train/Valid Acc.: 83.28%/82.64%
# 055/200 | Cost: 92276.90 | Train/Valid Acc.: 82.48%/82.46%
# 056/200 | Cost: 92315.24 | Train/Valid Acc.: 82.18%/81.78%
# 057/200 | Cost: 92257.86 | Train/Valid Acc.: 83.01%/82.46%
# 058/200 | Cost: 92244.37 | Train/Valid Acc.: 82.58%/82.32%
# 059/200 | Cost: 92337.03 | Train/Valid Acc.: 82.51%/82.18%
# 060/200 | Cost: 92199.28 | Train/Valid Acc.: 83.15%/82.72%
# 061/200 | Cost: 92349.89 | Train/Valid Acc.: 81.89%/81.42%
# 062/200 | Cost: 92155.78 | Train/Valid Acc.: 82.97%/82.32%
# 063/200 | Cost: 92268.88 | Train/Valid Acc.: 81.87%/81.58%
# 064/200 | Cost: 92318.14 | Train/Valid Acc.: 83.54%/82.62%
# 065/200 | Cost: 92282.45 | Train/Valid Acc.: 82.77%/82.34%
# 066/200 | Cost: 92226.53 | Train/Valid Acc.: 81.74%/81.54%
# 067/200 | Cost: 92163.70 | Train/Valid Acc.: 82.73%/82.48%
# 068/200 | Cost: 92166.93 | Train/Valid Acc.: 82.00%/81.70%
# 069/200 | Cost: 92194.31 | Train/Valid Acc.: 83.35%/82.82%
# 070/200 | Cost: 92065.13 | Train/Valid Acc.: 83.00%/82.60%
# 071/200 | Cost: 92098.68 | Train/Valid Acc.: 80.94%/80.94%
# 072/200 | Cost: 92181.30 | Train/Valid Acc.: 83.23%/82.90%
# 073/200 | Cost: 92227.69 | Train/Valid Acc.: 81.78%/81.60%
# 074/200 | Cost: 92123.39 | Train/Valid Acc.: 82.45%/82.38%
# 075/200 | Cost: 92106.61 | Train/Valid Acc.: 81.13%/80.96%
# 076/200 | Cost: 92462.47 | Train/Valid Acc.: 82.32%/82.76%
# 077/200 | Cost: 92233.79 | Train/Valid Acc.: 81.90%/81.74%
# 078/200 | Cost: 92246.30 | Train/Valid Acc.: 82.49%/81.92%
# 079/200 | Cost: 92065.63 | Train/Valid Acc.: 81.57%/81.34%
# 080/200 | Cost: 92087.60 | Train/Valid Acc.: 82.36%/82.00%
# 081/200 | Cost: 92193.28 | Train/Valid Acc.: 82.96%/82.94%
# 082/200 | Cost: 92190.06 | Train/Valid Acc.: 81.90%/81.34%
# 083/200 | Cost: 92173.17 | Train/Valid Acc.: 81.68%/81.52%
# 084/200 | Cost: 92103.28 | Train/Valid Acc.: 81.88%/81.58%
# 085/200 | Cost: 92112.93 | Train/Valid Acc.: 80.33%/80.36%
# 086/200 | Cost: 92151.92 | Train/Valid Acc.: 80.97%/80.70%
# 087/200 | Cost: 92187.24 | Train/Valid Acc.: 82.97%/82.38%
# 088/200 | Cost: 92135.85 | Train/Valid Acc.: 81.98%/82.26%
# 089/200 | Cost: 92057.62 | Train/Valid Acc.: 82.66%/82.14%
# 090/200 | Cost: 92067.93 | Train/Valid Acc.: 83.34%/83.00%
# 091/200 | Cost: 92001.12 | Train/Valid Acc.: 81.78%/81.56%
# 092/200 | Cost: 92213.35 | Train/Valid Acc.: 83.29%/82.88%
# 093/200 | Cost: 92069.46 | Train/Valid Acc.: 82.24%/82.18%
# 094/200 | Cost: 92077.29 | Train/Valid Acc.: 82.81%/82.72%
# 095/200 | Cost: 92070.81 | Train/Valid Acc.: 83.23%/83.14%
# 096/200 | Cost: 92035.69 | Train/Valid Acc.: 81.99%/81.88%
# 097/200 | Cost: 92037.97 | Train/Valid Acc.: 81.55%/81.52%
# 098/200 | Cost: 92058.69 | Train/Valid Acc.: 82.23%/82.16%
# 099/200 | Cost: 92262.50 | Train/Valid Acc.: 80.79%/80.10%
# 100/200 | Cost: 92106.65 | Train/Valid Acc.: 81.83%/81.60%
# 101/200 | Cost: 91988.16 | Train/Valid Acc.: 81.75%/81.36%
# 102/200 | Cost: 92060.97 | Train/Valid Acc.: 82.03%/81.68%
# 103/200 | Cost: 92020.97 | Train/Valid Acc.: 82.82%/82.48%
# 104/200 | Cost: 92027.00 | Train/Valid Acc.: 83.35%/83.20%
# 105/200 | Cost: 92222.12 | Train/Valid Acc.: 83.82%/83.66%
# 106/200 | Cost: 92132.63 | Train/Valid Acc.: 81.99%/81.44%
# 107/200 | Cost: 92263.47 | Train/Valid Acc.: 82.84%/82.54%
# 108/200 | Cost: 92061.34 | Train/Valid Acc.: 81.29%/81.34%
# 109/200 | Cost: 92165.05 | Train/Valid Acc.: 82.05%/82.02%
# 110/200 | Cost: 92000.63 | Train/Valid Acc.: 82.09%/82.02%
# 111/200 | Cost: 91990.41 | Train/Valid Acc.: 82.70%/82.00%
# 112/200 | Cost: 92081.29 | Train/Valid Acc.: 83.16%/82.72%
# 113/200 | Cost: 92122.09 | Train/Valid Acc.: 82.01%/81.80%
# 114/200 | Cost: 92006.00 | Train/Valid Acc.: 81.88%/81.86%
# 115/200 | Cost: 91999.13 | Train/Valid Acc.: 82.62%/82.28%
# 116/200 | Cost: 92102.03 | Train/Valid Acc.: 82.29%/81.74%
# 117/200 | Cost: 92133.73 | Train/Valid Acc.: 82.27%/81.98%
# 118/200 | Cost: 92011.75 | Train/Valid Acc.: 83.17%/83.18%
# 119/200 | Cost: 92024.91 | Train/Valid Acc.: 81.06%/80.72%
# 120/200 | Cost: 92021.67 | Train/Valid Acc.: 82.29%/81.92%
# 121/200 | Cost: 91956.55 | Train/Valid Acc.: 82.64%/82.30%
# 122/200 | Cost: 92015.77 | Train/Valid Acc.: 81.24%/80.98%
# 123/200 | Cost: 91961.05 | Train/Valid Acc.: 81.39%/81.28%
# 124/200 | Cost: 92072.59 | Train/Valid Acc.: 82.73%/82.46%
# 125/200 | Cost: 92095.76 | Train/Valid Acc.: 82.75%/82.26%
# 126/200 | Cost: 91942.11 | Train/Valid Acc.: 82.92%/82.84%
# 127/200 | Cost: 92128.55 | Train/Valid Acc.: 79.98%/79.80%
# 128/200 | Cost: 91964.70 | Train/Valid Acc.: 80.49%/80.42%
# 129/200 | Cost: 92038.42 | Train/Valid Acc.: 82.26%/81.92%
# 130/200 | Cost: 91923.73 | Train/Valid Acc.: 81.32%/81.52%
# 131/200 | Cost: 92000.59 | Train/Valid Acc.: 81.61%/81.14%
# 132/200 | Cost: 92035.72 | Train/Valid Acc.: 82.67%/82.72%
# 133/200 | Cost: 92023.88 | Train/Valid Acc.: 81.27%/80.82%
# 134/200 | Cost: 92030.25 | Train/Valid Acc.: 82.56%/81.76%
# 135/200 | Cost: 91961.02 | Train/Valid Acc.: 83.10%/83.08%
# 136/200 | Cost: 92115.82 | Train/Valid Acc.: 80.95%/80.84%
# 137/200 | Cost: 91995.04 | Train/Valid Acc.: 83.01%/82.84%
# 138/200 | Cost: 91872.43 | Train/Valid Acc.: 81.61%/81.42%
# 139/200 | Cost: 91930.05 | Train/Valid Acc.: 83.02%/82.52%
# 140/200 | Cost: 92056.25 | Train/Valid Acc.: 81.15%/81.02%
# 141/200 | Cost: 91985.92 | Train/Valid Acc.: 83.16%/82.68%
# 142/200 | Cost: 91952.34 | Train/Valid Acc.: 82.33%/81.98%
# 143/200 | Cost: 92000.43 | Train/Valid Acc.: 83.09%/82.38%
# 144/200 | Cost: 92066.60 | Train/Valid Acc.: 81.09%/80.46%
# 145/200 | Cost: 92069.44 | Train/Valid Acc.: 83.29%/82.60%
# 146/200 | Cost: 92072.74 | Train/Valid Acc.: 79.81%/79.62%
# 147/200 | Cost: 91966.79 | Train/Valid Acc.: 82.47%/81.82%
# 148/200 | Cost: 92091.33 | Train/Valid Acc.: 83.00%/82.34%
# 149/200 | Cost: 92036.60 | Train/Valid Acc.: 82.29%/82.16%
# 150/200 | Cost: 92162.84 | Train/Valid Acc.: 82.20%/82.02%
# 151/200 | Cost: 91966.31 | Train/Valid Acc.: 82.86%/82.36%
# 152/200 | Cost: 91840.95 | Train/Valid Acc.: 82.87%/82.50%
# 153/200 | Cost: 91800.59 | Train/Valid Acc.: 82.01%/81.76%
# 154/200 | Cost: 91948.59 | Train/Valid Acc.: 82.12%/81.98%
# 155/200 | Cost: 91996.06 | Train/Valid Acc.: 81.71%/81.78%
# 156/200 | Cost: 92061.15 | Train/Valid Acc.: 81.56%/81.54%
# 157/200 | Cost: 91910.32 | Train/Valid Acc.: 81.59%/81.16%
# 158/200 | Cost: 92006.34 | Train/Valid Acc.: 82.67%/82.52%
# 159/200 | Cost: 92096.49 | Train/Valid Acc.: 83.18%/82.54%
# 160/200 | Cost: 91993.73 | Train/Valid Acc.: 83.35%/82.48%
# 161/200 | Cost: 91855.52 | Train/Valid Acc.: 81.60%/81.34%
# 162/200 | Cost: 91948.53 | Train/Valid Acc.: 82.67%/82.18%
# 163/200 | Cost: 91912.20 | Train/Valid Acc.: 82.47%/82.36%
# 164/200 | Cost: 91951.71 | Train/Valid Acc.: 82.26%/82.00%
# 165/200 | Cost: 91943.96 | Train/Valid Acc.: 82.70%/82.60%
# 166/200 | Cost: 91971.08 | Train/Valid Acc.: 82.02%/82.04%
# 167/200 | Cost: 91935.16 | Train/Valid Acc.: 81.77%/81.22%
# 168/200 | Cost: 91877.07 | Train/Valid Acc.: 81.81%/81.60%
# 169/200 | Cost: 91906.70 | Train/Valid Acc.: 81.68%/81.52%
# 170/200 | Cost: 91956.46 | Train/Valid Acc.: 82.19%/81.76%
# 171/200 | Cost: 91960.09 | Train/Valid Acc.: 82.93%/82.92%
# 172/200 | Cost: 91895.71 | Train/Valid Acc.: 82.57%/82.34%
# 173/200 | Cost: 91989.81 | Train/Valid Acc.: 81.58%/81.70%
# 174/200 | Cost: 91892.43 | Train/Valid Acc.: 82.60%/81.92%
# 175/200 | Cost: 92012.22 | Train/Valid Acc.: 81.12%/81.08%
# 176/200 | Cost: 91924.57 | Train/Valid Acc.: 82.92%/82.62%
# 177/200 | Cost: 92003.51 | Train/Valid Acc.: 83.15%/83.26%
# 178/200 | Cost: 91943.75 | Train/Valid Acc.: 81.56%/81.62%
# 179/200 | Cost: 92011.24 | Train/Valid Acc.: 83.03%/82.62%
# 180/200 | Cost: 91909.10 | Train/Valid Acc.: 82.24%/82.10%
# 181/200 | Cost: 92018.35 | Train/Valid Acc.: 80.08%/79.96%
# 182/200 | Cost: 92060.06 | Train/Valid Acc.: 82.28%/81.74%
# 183/200 | Cost: 92002.96 | Train/Valid Acc.: 80.55%/80.58%
# 184/200 | Cost: 91962.43 | Train/Valid Acc.: 82.67%/82.82%
# 185/200 | Cost: 91869.32 | Train/Valid Acc.: 81.06%/80.92%
# 186/200 | Cost: 91849.68 | Train/Valid Acc.: 82.16%/82.18%
# 187/200 | Cost: 91966.34 | Train/Valid Acc.: 81.86%/81.98%
# 188/200 | Cost: 91989.93 | Train/Valid Acc.: 82.51%/82.02%
# 189/200 | Cost: 91882.21 | Train/Valid Acc.: 82.98%/82.90%
# 190/200 | Cost: 91909.14 | Train/Valid Acc.: 81.96%/81.66%
# 191/200 | Cost: 91971.86 | Train/Valid Acc.: 81.23%/81.06%
# 192/200 | Cost: 91858.76 | Train/Valid Acc.: 82.41%/81.70%
# 193/200 | Cost: 92027.92 | Train/Valid Acc.: 82.26%/82.18%
# 194/200 | Cost: 91962.36 | Train/Valid Acc.: 82.15%/82.02%
# 195/200 | Cost: 91895.57 | Train/Valid Acc.: 80.99%/80.94%
# 196/200 | Cost: 91944.62 | Train/Valid Acc.: 82.69%/82.00%
# 197/200 | Cost: 91966.05 | Train/Valid Acc.: 81.65%/81.54%
# 198/200 | Cost: 92035.71 | Train/Valid Acc.: 83.27%/83.52%
# 199/200 | Cost: 91997.55 | Train/Valid Acc.: 82.58%/82.40%
# 200/200 | Cost: 91906.87 | Train/Valid Acc.: 81.90%/81.84%
# Test accuracy: 82.87%
# Train accuracy: 81.90%
# Val accuracy: 81.84%
# ===================================l2: 4================================
# 001/200 | Cost: 124094.72 | Train/Valid Acc.: 69.93%/70.06%
# 002/200 | Cost: 112966.13 | Train/Valid Acc.: 75.15%/75.04%
# 003/200 | Cost: 110250.77 | Train/Valid Acc.: 76.37%/76.24%
# 004/200 | Cost: 109167.24 | Train/Valid Acc.: 76.69%/76.48%
# 005/200 | Cost: 108504.22 | Train/Valid Acc.: 78.25%/77.84%
# 006/200 | Cost: 108093.10 | Train/Valid Acc.: 75.17%/75.06%
# 007/200 | Cost: 107857.00 | Train/Valid Acc.: 77.46%/76.98%
# 008/200 | Cost: 107515.78 | Train/Valid Acc.: 77.09%/76.78%
# 009/200 | Cost: 107572.88 | Train/Valid Acc.: 74.40%/73.62%
# 010/200 | Cost: 107453.82 | Train/Valid Acc.: 77.68%/76.86%
# 011/200 | Cost: 107262.94 | Train/Valid Acc.: 80.00%/79.32%
# 012/200 | Cost: 107094.59 | Train/Valid Acc.: 78.17%/77.56%
# 013/200 | Cost: 107195.42 | Train/Valid Acc.: 78.23%/78.06%
# 014/200 | Cost: 106969.58 | Train/Valid Acc.: 73.19%/72.88%
# 015/200 | Cost: 106742.18 | Train/Valid Acc.: 75.79%/75.12%
# 016/200 | Cost: 106832.23 | Train/Valid Acc.: 77.75%/77.36%
# 017/200 | Cost: 106677.45 | Train/Valid Acc.: 76.56%/75.78%
# 018/200 | Cost: 106662.60 | Train/Valid Acc.: 76.09%/75.52%
# 019/200 | Cost: 106684.23 | Train/Valid Acc.: 74.56%/73.88%
# 020/200 | Cost: 106566.13 | Train/Valid Acc.: 76.05%/75.56%
# 021/200 | Cost: 106510.25 | Train/Valid Acc.: 77.36%/76.62%
# 022/200 | Cost: 106447.17 | Train/Valid Acc.: 75.80%/75.10%
# 023/200 | Cost: 106280.39 | Train/Valid Acc.: 76.49%/76.06%
# 024/200 | Cost: 106423.72 | Train/Valid Acc.: 78.17%/77.60%
# 025/200 | Cost: 106375.53 | Train/Valid Acc.: 77.78%/77.74%
# 026/200 | Cost: 106368.07 | Train/Valid Acc.: 77.71%/77.26%
# 027/200 | Cost: 106259.82 | Train/Valid Acc.: 76.30%/75.74%
# 028/200 | Cost: 106284.69 | Train/Valid Acc.: 77.05%/76.68%
# 029/200 | Cost: 106221.18 | Train/Valid Acc.: 78.69%/77.98%
# 030/200 | Cost: 106232.42 | Train/Valid Acc.: 77.36%/76.48%
# 031/200 | Cost: 106257.22 | Train/Valid Acc.: 76.10%/75.86%
# 032/200 | Cost: 106266.97 | Train/Valid Acc.: 76.49%/76.10%
# 033/200 | Cost: 106164.94 | Train/Valid Acc.: 75.13%/74.08%
# 034/200 | Cost: 106070.63 | Train/Valid Acc.: 75.71%/74.92%
# 035/200 | Cost: 106108.08 | Train/Valid Acc.: 78.05%/77.30%
# 036/200 | Cost: 106112.23 | Train/Valid Acc.: 79.47%/78.76%
# 037/200 | Cost: 106043.02 | Train/Valid Acc.: 78.07%/77.42%
# 038/200 | Cost: 105978.33 | Train/Valid Acc.: 76.97%/76.18%
# 039/200 | Cost: 106087.58 | Train/Valid Acc.: 75.88%/75.34%
# 040/200 | Cost: 106040.85 | Train/Valid Acc.: 77.73%/76.98%
# 041/200 | Cost: 105978.38 | Train/Valid Acc.: 76.38%/75.42%
# 042/200 | Cost: 106064.25 | Train/Valid Acc.: 78.85%/77.86%
# 043/200 | Cost: 106117.55 | Train/Valid Acc.: 76.45%/75.86%
# 044/200 | Cost: 105940.28 | Train/Valid Acc.: 77.82%/76.88%
# 045/200 | Cost: 105979.71 | Train/Valid Acc.: 78.42%/77.92%
# 046/200 | Cost: 105949.69 | Train/Valid Acc.: 76.19%/76.12%
# 047/200 | Cost: 105867.15 | Train/Valid Acc.: 77.82%/77.34%
# 048/200 | Cost: 105983.76 | Train/Valid Acc.: 78.23%/77.14%
# 049/200 | Cost: 105874.79 | Train/Valid Acc.: 77.22%/76.66%
# 050/200 | Cost: 105919.72 | Train/Valid Acc.: 76.06%/75.62%
# 051/200 | Cost: 105847.52 | Train/Valid Acc.: 74.91%/74.74%
# 052/200 | Cost: 105855.88 | Train/Valid Acc.: 77.28%/77.02%
# 053/200 | Cost: 105932.67 | Train/Valid Acc.: 76.49%/76.00%
# 054/200 | Cost: 105866.67 | Train/Valid Acc.: 79.07%/78.16%
# 055/200 | Cost: 105815.37 | Train/Valid Acc.: 77.77%/77.34%
# 056/200 | Cost: 105855.47 | Train/Valid Acc.: 77.52%/76.82%
# 057/200 | Cost: 105799.84 | Train/Valid Acc.: 78.37%/77.80%
# 058/200 | Cost: 105760.60 | Train/Valid Acc.: 77.72%/77.44%
# 059/200 | Cost: 105877.60 | Train/Valid Acc.: 77.98%/76.84%
# 060/200 | Cost: 105752.82 | Train/Valid Acc.: 78.91%/78.28%
# 061/200 | Cost: 105888.55 | Train/Valid Acc.: 76.85%/75.84%
# 062/200 | Cost: 105689.49 | Train/Valid Acc.: 78.55%/77.82%
# 063/200 | Cost: 105818.88 | Train/Valid Acc.: 76.98%/76.18%
# 064/200 | Cost: 105862.14 | Train/Valid Acc.: 79.29%/78.42%
# 065/200 | Cost: 105857.87 | Train/Valid Acc.: 78.11%/77.88%
# 066/200 | Cost: 105753.96 | Train/Valid Acc.: 76.13%/76.16%
# 067/200 | Cost: 105722.97 | Train/Valid Acc.: 78.10%/77.70%
# 068/200 | Cost: 105753.39 | Train/Valid Acc.: 77.14%/76.60%
# 069/200 | Cost: 105752.62 | Train/Valid Acc.: 79.07%/78.34%
# 070/200 | Cost: 105621.28 | Train/Valid Acc.: 78.77%/78.04%
# 071/200 | Cost: 105635.11 | Train/Valid Acc.: 75.55%/75.16%
# 072/200 | Cost: 105737.11 | Train/Valid Acc.: 79.02%/78.32%
# 073/200 | Cost: 105769.91 | Train/Valid Acc.: 77.03%/76.96%
# 074/200 | Cost: 105662.68 | Train/Valid Acc.: 77.78%/77.22%
# 075/200 | Cost: 105677.00 | Train/Valid Acc.: 76.07%/75.02%
# 076/200 | Cost: 106006.89 | Train/Valid Acc.: 77.62%/77.08%
# 077/200 | Cost: 105803.69 | Train/Valid Acc.: 76.75%/76.12%
# 078/200 | Cost: 105815.69 | Train/Valid Acc.: 77.65%/76.64%
# 079/200 | Cost: 105596.94 | Train/Valid Acc.: 76.68%/76.12%
# 080/200 | Cost: 105632.16 | Train/Valid Acc.: 77.41%/77.10%
# 081/200 | Cost: 105752.30 | Train/Valid Acc.: 78.37%/77.66%
# 082/200 | Cost: 105767.89 | Train/Valid Acc.: 76.51%/75.70%
# 083/200 | Cost: 105738.67 | Train/Valid Acc.: 76.66%/76.26%
# 084/200 | Cost: 105669.99 | Train/Valid Acc.: 77.32%/76.44%
# 085/200 | Cost: 105642.34 | Train/Valid Acc.: 74.77%/74.14%
# 086/200 | Cost: 105724.66 | Train/Valid Acc.: 75.55%/74.74%
# 087/200 | Cost: 105743.89 | Train/Valid Acc.: 78.36%/77.64%
# 088/200 | Cost: 105696.03 | Train/Valid Acc.: 77.08%/76.58%
# 089/200 | Cost: 105623.12 | Train/Valid Acc.: 78.26%/77.08%
# 090/200 | Cost: 105654.15 | Train/Valid Acc.: 79.34%/78.60%
# 091/200 | Cost: 105532.17 | Train/Valid Acc.: 76.55%/76.40%
# 092/200 | Cost: 105814.23 | Train/Valid Acc.: 78.99%/78.00%
# 093/200 | Cost: 105640.06 | Train/Valid Acc.: 77.15%/76.70%
# 094/200 | Cost: 105617.63 | Train/Valid Acc.: 78.45%/77.84%
# 095/200 | Cost: 105647.23 | Train/Valid Acc.: 79.16%/78.70%
# 096/200 | Cost: 105599.90 | Train/Valid Acc.: 77.01%/76.26%
# 097/200 | Cost: 105590.96 | Train/Valid Acc.: 76.47%/75.74%
# 098/200 | Cost: 105638.07 | Train/Valid Acc.: 77.19%/76.54%
# 099/200 | Cost: 105819.32 | Train/Valid Acc.: 73.88%/73.58%
# 100/200 | Cost: 105702.78 | Train/Valid Acc.: 76.97%/76.66%
# 101/200 | Cost: 105544.30 | Train/Valid Acc.: 76.75%/76.24%
# 102/200 | Cost: 105595.11 | Train/Valid Acc.: 77.11%/76.46%
# 103/200 | Cost: 105566.50 | Train/Valid Acc.: 78.23%/77.44%
# 104/200 | Cost: 105580.13 | Train/Valid Acc.: 79.31%/78.74%
# 105/200 | Cost: 105806.83 | Train/Valid Acc.: 80.16%/79.30%
# 106/200 | Cost: 105721.94 | Train/Valid Acc.: 77.29%/76.50%
# 107/200 | Cost: 105833.78 | Train/Valid Acc.: 78.32%/77.40%
# 108/200 | Cost: 105625.42 | Train/Valid Acc.: 76.29%/75.64%
# 109/200 | Cost: 105745.10 | Train/Valid Acc.: 77.50%/77.02%
# 110/200 | Cost: 105576.25 | Train/Valid Acc.: 77.21%/76.64%
# 111/200 | Cost: 105553.04 | Train/Valid Acc.: 78.14%/77.08%
# 112/200 | Cost: 105645.64 | Train/Valid Acc.: 78.47%/78.02%
# 113/200 | Cost: 105721.05 | Train/Valid Acc.: 76.69%/76.30%
# 114/200 | Cost: 105565.44 | Train/Valid Acc.: 77.00%/76.36%
# 115/200 | Cost: 105570.73 | Train/Valid Acc.: 78.13%/77.38%
# 116/200 | Cost: 105675.20 | Train/Valid Acc.: 77.56%/76.82%
# 117/200 | Cost: 105708.65 | Train/Valid Acc.: 77.17%/76.76%
# 118/200 | Cost: 105592.69 | Train/Valid Acc.: 78.90%/78.34%
# 119/200 | Cost: 105604.85 | Train/Valid Acc.: 76.35%/75.64%
# 120/200 | Cost: 105601.13 | Train/Valid Acc.: 77.32%/76.88%
# 121/200 | Cost: 105510.95 | Train/Valid Acc.: 78.13%/77.24%
# 122/200 | Cost: 105607.01 | Train/Valid Acc.: 75.99%/75.26%
# 123/200 | Cost: 105532.29 | Train/Valid Acc.: 76.03%/75.18%
# 124/200 | Cost: 105648.79 | Train/Valid Acc.: 78.23%/77.34%
# 125/200 | Cost: 105711.19 | Train/Valid Acc.: 78.13%/77.58%
# 126/200 | Cost: 105534.82 | Train/Valid Acc.: 78.53%/77.96%
# 127/200 | Cost: 105714.15 | Train/Valid Acc.: 74.81%/74.24%
# 128/200 | Cost: 105502.30 | Train/Valid Acc.: 75.08%/74.56%
# 129/200 | Cost: 105614.26 | Train/Valid Acc.: 77.41%/76.58%
# 130/200 | Cost: 105490.25 | Train/Valid Acc.: 76.31%/75.76%
# 131/200 | Cost: 105591.88 | Train/Valid Acc.: 76.19%/75.54%
# 132/200 | Cost: 105642.25 | Train/Valid Acc.: 77.88%/77.48%
# 133/200 | Cost: 105593.43 | Train/Valid Acc.: 76.01%/75.28%
# 134/200 | Cost: 105618.70 | Train/Valid Acc.: 77.56%/76.72%
# 135/200 | Cost: 105557.45 | Train/Valid Acc.: 79.02%/78.66%
# 136/200 | Cost: 105700.42 | Train/Valid Acc.: 75.81%/75.32%
# 137/200 | Cost: 105566.24 | Train/Valid Acc.: 78.67%/77.86%
# 138/200 | Cost: 105459.07 | Train/Valid Acc.: 76.48%/75.86%
# 139/200 | Cost: 105527.17 | Train/Valid Acc.: 78.80%/77.74%
# 140/200 | Cost: 105672.44 | Train/Valid Acc.: 76.18%/74.96%
# 141/200 | Cost: 105593.69 | Train/Valid Acc.: 78.59%/78.10%
# 142/200 | Cost: 105545.72 | Train/Valid Acc.: 77.34%/76.56%
# 143/200 | Cost: 105598.34 | Train/Valid Acc.: 78.64%/77.68%
# 144/200 | Cost: 105658.50 | Train/Valid Acc.: 75.89%/74.80%
# 145/200 | Cost: 105692.02 | Train/Valid Acc.: 79.16%/78.22%
# 146/200 | Cost: 105658.53 | Train/Valid Acc.: 74.22%/73.42%
# 147/200 | Cost: 105555.26 | Train/Valid Acc.: 77.72%/77.04%
# 148/200 | Cost: 105729.21 | Train/Valid Acc.: 77.87%/77.22%
# 149/200 | Cost: 105624.44 | Train/Valid Acc.: 77.80%/77.32%
# 150/200 | Cost: 105802.09 | Train/Valid Acc.: 77.02%/76.12%
# 151/200 | Cost: 105590.66 | Train/Valid Acc.: 78.44%/77.52%
# 152/200 | Cost: 105419.47 | Train/Valid Acc.: 78.43%/77.88%
# 153/200 | Cost: 105386.77 | Train/Valid Acc.: 77.07%/76.38%
# 154/200 | Cost: 105545.85 | Train/Valid Acc.: 77.45%/76.62%
# 155/200 | Cost: 105600.66 | Train/Valid Acc.: 76.81%/76.26%
# 156/200 | Cost: 105668.14 | Train/Valid Acc.: 76.40%/75.68%
# 157/200 | Cost: 105484.86 | Train/Valid Acc.: 76.46%/75.92%
# 158/200 | Cost: 105596.34 | Train/Valid Acc.: 77.95%/77.50%
# 159/200 | Cost: 105715.60 | Train/Valid Acc.: 78.21%/77.22%
# 160/200 | Cost: 105631.26 | Train/Valid Acc.: 78.74%/77.42%
# 161/200 | Cost: 105453.54 | Train/Valid Acc.: 76.67%/76.08%
# 162/200 | Cost: 105571.54 | Train/Valid Acc.: 77.81%/77.34%
# 163/200 | Cost: 105529.80 | Train/Valid Acc.: 78.19%/77.60%
# 164/200 | Cost: 105569.46 | Train/Valid Acc.: 77.62%/76.54%
# 165/200 | Cost: 105554.34 | Train/Valid Acc.: 77.84%/77.28%
# 166/200 | Cost: 105579.74 | Train/Valid Acc.: 77.02%/76.52%
# 167/200 | Cost: 105541.01 | Train/Valid Acc.: 76.84%/75.70%
# 168/200 | Cost: 105468.41 | Train/Valid Acc.: 76.54%/75.78%
# 169/200 | Cost: 105522.15 | Train/Valid Acc.: 76.52%/75.76%
# 170/200 | Cost: 105578.69 | Train/Valid Acc.: 77.05%/76.16%
# 171/200 | Cost: 105586.01 | Train/Valid Acc.: 78.55%/78.22%
# 172/200 | Cost: 105514.04 | Train/Valid Acc.: 77.91%/77.50%
# 173/200 | Cost: 105588.33 | Train/Valid Acc.: 76.30%/75.50%
# 174/200 | Cost: 105503.90 | Train/Valid Acc.: 77.91%/76.92%
# 175/200 | Cost: 105584.33 | Train/Valid Acc.: 75.41%/75.08%
# 176/200 | Cost: 105517.04 | Train/Valid Acc.: 78.25%/77.72%
# 177/200 | Cost: 105615.57 | Train/Valid Acc.: 79.06%/78.58%
# 178/200 | Cost: 105556.19 | Train/Valid Acc.: 76.25%/75.48%
# 179/200 | Cost: 105639.80 | Train/Valid Acc.: 78.50%/77.88%
# 180/200 | Cost: 105505.38 | Train/Valid Acc.: 77.25%/76.70%
# 181/200 | Cost: 105633.15 | Train/Valid Acc.: 74.25%/73.52%
# 182/200 | Cost: 105711.67 | Train/Valid Acc.: 76.69%/76.30%
# 183/200 | Cost: 105647.47 | Train/Valid Acc.: 74.97%/74.12%
# 184/200 | Cost: 105582.61 | Train/Valid Acc.: 78.11%/78.16%
# 185/200 | Cost: 105454.41 | Train/Valid Acc.: 75.57%/75.08%
# 186/200 | Cost: 105459.15 | Train/Valid Acc.: 77.27%/76.82%
# 187/200 | Cost: 105601.45 | Train/Valid Acc.: 77.10%/76.76%
# 188/200 | Cost: 105598.35 | Train/Valid Acc.: 77.99%/76.70%
# 189/200 | Cost: 105512.90 | Train/Valid Acc.: 78.62%/78.04%
# 190/200 | Cost: 105554.74 | Train/Valid Acc.: 77.20%/76.58%
# 191/200 | Cost: 105583.57 | Train/Valid Acc.: 76.07%/75.56%
# 192/200 | Cost: 105462.82 | Train/Valid Acc.: 77.40%/76.62%
# 193/200 | Cost: 105628.12 | Train/Valid Acc.: 77.31%/76.80%
# 194/200 | Cost: 105590.79 | Train/Valid Acc.: 76.78%/76.30%
# 195/200 | Cost: 105477.05 | Train/Valid Acc.: 75.39%/75.02%
# 196/200 | Cost: 105564.49 | Train/Valid Acc.: 78.06%/76.92%
# 197/200 | Cost: 105589.57 | Train/Valid Acc.: 76.57%/75.68%
# 198/200 | Cost: 105638.70 | Train/Valid Acc.: 79.05%/78.86%
# 199/200 | Cost: 105621.12 | Train/Valid Acc.: 77.88%/77.62%
# 200/200 | Cost: 105506.36 | Train/Valid Acc.: 77.11%/76.56%
# Test accuracy: 77.96%
# Train accuracy: 77.11%
# Val accuracy: 76.56%

# %%
# Plot examples of misclassified images
miscl_img = X_test[y_test != y_test_pred][:25]
correct_lab = y_test[y_test != y_test_pred][:25]
miscl_lab = y_test_pred[y_test != y_test_pred][:25]

fig, ax = plt.subplots(nrows=5, ncols=5, sharex=True, sharey=True)
ax = ax.flatten()
for i in range(25):
    img = miscl_img[i].reshape(28, 28)
    ax[i].imshow(img, cmap='gray', interpolation='nearest')
    ax[i].set_title('%d) t: %d p: %d' % (i+1, correct_lab[i], miscl_lab[i]))

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 1 [60 marks]
#
# ### Part A: Optimize L2 Regularization
#
# In the provided code, an L2 regularization parameter, `l2`, was set to 10. Your task is to find the optimal value for `l2` that can improve the model's performance. After selecting the optimal `l2` value, report the following accuracies:
# - Training accuracy
# - Validation accuracy
# - Test accuracy
#
# Discuss in your report why these accuracies changed significantly when you experimented with different `l2` values. Hint: Try lower values of `l2`.
#
# ### Part B: Explore Activation Functions
#
# Modify the code to use different activation functions in the hidden layer, specifically `tanh` and `relu`. Keep the output layer activation function as `sigmoid` since the output needs to be in the range 0-1 for cross-entropy loss calculation. Use the previously optimized `l2` value for this part. Report the effects of using these activation functions on the training, validation, and test accuracies.
#
# Please provide detailed explanations of the observed changes in accuracy and any insights you gain from these experiments.

# %% [markdown]
# ## Task 2 [40 marks]
#
# For this task, use the optimized `l2` value obtained from Task 1 and the `sigmoid` activation function for your model. This task focuses on evaluating the model's performance and reporting various metrics.
#
# ### Part A: Confusion Matrix
#
# Write code to display the confusion matrix of the test data. Include both the code and the generated figure in your report.
#
# ### Part B: Precision, Recall, and F1-Score Calculation
#
# Write code to estimate precision, recall, and F1-score for the test data, considering each class separately. Include both the code and the results in your report.
#
# Reminder: The formulas for these metrics are as follows:
#
# - Accuracy:
#   \begin{equation}
#       Accuracy = \frac{TN + TP}{TN + TP + FN + FP}
#   \end{equation}
#
# - Precision:
#   \begin{equation}
#       Precision = \frac{TP}{TP + FP}
#   \end{equation}
#
# - Recall:
#   \begin{equation}
#       Recall = \frac{TP}{TP + FN}
#   \end{equation}
#
# - F1-Score:
#   \begin{equation}
#       F1\text{-}score = \frac{2 \cdot (Precision \cdot Recall)}{Precision + Recall}
#   \end{equation}
#
# Where:
# - TN = True Negative
# - TP = True Positive
# - FN = False Negative
# - FP = False Positive
#
# For reference and a useful diagram, you can visit the Wikipedia page on [Precision and Recall](https://en.wikipedia.org/wiki/Precision_and_recall).
#
# Please ensure you provide both the code and the calculated results in your report for a comprehensive evaluation of the model's performance.
