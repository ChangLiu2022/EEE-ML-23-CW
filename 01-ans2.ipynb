# %% [markdown]
# ## Task 1 [40 marks]
#
# **Perceptron Algorithm for Setosa vs. Versicolor Classification**
#
# In this task, we will replicate the previous steps of the tutorial to perform binary classification between the Setosa and Versicolor classes using the same two features, namely petal length and sepal length. Your report should include the following components:
#
# ### Steps to Follow:
#
# 1. **Data Selection:**
#    - Choose the Setosa and Versicolor classes from the Iris dataset.
#    - Select the petal length and sepal length features as done in the previous task.
#
# 2. **Data Visualisation:**
#    - Generate a plot that clearly demonstrates the linear separability of the Setosa and Versicolor classes based on the selected features.
#
# 3. **Perceptron Algorithm Execution:**
#    - Implement the perceptron algorithm for the Setosa vs. Versicolor classification task.
#    - Specify the number of iterations to perform during the algorithm execution.
#
# 4. **Misclassification Analysis:**
#    - Create a plot illustrating the change in misclassified samples across the iterations of the perceptron algorithm.
#
# 5. **Final Weight Reporting:**
#    - Report the final weight values obtained as a result of the perceptron algorithm.
#
# 6. **Code Showcase:**
#    - Include the code segments that you modified or added for each step of the process.
#    - Discuss the specific adaptations you made to the code to suit the Setosa vs. Versicolor classification.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from pandas.plotting import scatter_matrix
import warnings
warnings.filterwarnings('ignore')

from sklearn.datasets import load_iris
iris = load_iris()

# This command generates a decsription of the dataset if you need more information
print(iris['DESCR'])

from pandas.plotting import scatter_matrix
import pandas as pd

iris_data = pd.DataFrame(data=iris['data'],columns=iris['feature_names'])

"""
Generate a scatter matrix plot to visualize the relationships between different features in the Iris dataset.
Each subplot in the matrix shows the scatter plot between two different features, while histograms on the diagonal
show the distribution of each individual feature. The color of points in the scatter plots is determined by the
corresponding class labels (Setosa, Versicolor, Virginica), where each class is assigned a distinct color.
The plot provides insights into possible patterns, correlations, and separations among features, aiding in data exploration.
"""

iris_data["target"] = iris['target']
color_dictionary = {1: "#FE010A", 2: "#2722DD", 3: "#1BE41D"}
colors = iris_data["target"].map(lambda x: color_dictionary.get(x + 1))
ax = scatter_matrix(iris_data, color=colors, alpha=0.8, figsize=(10, 10), diagonal='hist')

iris_data
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
#     ============== ==== ==== ======= ===== ====================
#
#     :Missing Attribute Values: None
#     :Class Distribution: 33.3% for each of 3 classes.
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. topic:: References
#
#    - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#      Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#      Mathematical Statistics" (John Wiley, NY, 1950).
#    - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#      (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#    - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#      Structure and Classification Rule for Recognition in Partially Exposed
#      Environments".  IEEE Transactions on Pattern Analysis and Machine
#      Intelligence, Vol. PAMI-2, No. 1, 67-71.
#    - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#      on Information Theory, May 1972, 431-433.
#    - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#      conceptual clustering system finds 3 classes in the data.
#    - Many, many more ...
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
versicolour_label = iris_data.iloc[50:100,4].values 
virginica_label = iris_data.iloc[100:150,4].values # changed to [100:150] to get virginica
labels = np.concatenate((versicolour_label, virginica_label))#change concatenate content
y = np.where(labels == 1, -1, 1) #change label identification


X_versicolour = iris_data.iloc[50:100, [0,2]]
X_virginica = iris_data.iloc[100:150, [0,2]]  # changed to [100:150] to get virginica
X = np.concatenate((X_versicolour, X_virginica)) #change concatenate content

plt.scatter(X[:50,0],X[:50,1],color='red',marker='o',label='Versicolor') #change label
plt.scatter(X[50:100,0],X[50:100,1],color='blue',marker='o',label='Virginica') #change label
plt.title("Sepal Length vs Petal Length")
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.legend(loc='upper left')
plt.show()

# %%
def predict(W, X):
        """ Return class label after each setp """
        return np.where(net_input(W, X) >= 0.0, 1, -1)

def net_input(W, X):
        """ Calculate net input """
        return np.dot(X, W[1:]) + W[0]

def plot_boundary(W, X):
    """Function to plot the boundary defined by the weights. Given equation."""
    """w0 + w1*x1 + w2*x2 = 0, used to generate the line."""

    # Calculate the slope and y-intercept of the boundary line
    slope = -W[1] / W[2]
    intercept = -W[0] / W[2]

    # Get the minimum and maximum x values from the dataset
    x_min = np.min(X[:, 0])
    x_max = np.max(X[:, 0])

    # Generate points for the boundary line to cover the whole plot
    x_vals = np.array([x_min, x_max])
    y_vals = slope * x_vals + intercept

    # This part here define the x-axis and y-axis style according to the data we are using
    plt.figure(figsize=(5, 4))
    plt.scatter(X[:50, 0], X[:50, 1], color='red', marker='o', label='Versicolour')
    plt.scatter(X[50:100, 0], X[50:100, 1], color='blue', marker='o', label='Virginica') #change the label name
    plt.title("Sepal Length vs Petal Length")
    plt.xlabel('Sepal Length')
    plt.ylabel('Petal Length')
    plt.legend(loc='upper left')

    # Plot the line using the calculated points
    plt.plot(x_vals, y_vals, 'black')

    plt.show()

def plot_errors(error,best_errors):
    """ Function to plot number of misclassified samples """
    plt.plot(range(1, len(error) + 1), error,marker='o', label='error')
    plt.plot(range(1, len(error) + 1), best_errors,marker='o', label='best error')
    plt.xlabel('Iterations')
    plt.ylabel('Number of misclassifications')
    plt.legend(loc='lower left')
    plt.show()

def fit(n_iter, X, y):
        W = np.zeros(1 + X.shape[1])
        errors_ = []
        best_errors_ = []
        W_pocket = np.zeros(1 + X.shape[1])
        best_error = int(X.shape[0]/2) #all wrong
        for i in range(n_iter):
            for j, (xi, target) in enumerate(zip(X,y)):
         #     update = target - predict(W, xi)
         #     W += 0.5*update*np.append(1,xi)
              if predict(W, xi) != target:
                  W = W + target * np.append(1,xi)
            # errors on whole dataset
            errors = 0
            for j, (xi, target) in enumerate(zip(X, y)):
                if predict(W, xi) != target:
                    errors += 1
            # -------------------------------------------
            errors_.append(errors)
            if(errors <= best_error):
                best_error = errors
                W_pocket = W
            best_errors_.append(best_error)
            i += 1
            print ("Iteration: ", i)
            print("Weights: ", W)
            print("Misclassified Samples: ", errors)
            print("Pocket Weights: ", W_pocket)
            print("Least # Misclassified Samples So far: ", best_error)
            plot_boundary(W,X) # When weights are updated we plot the boundary
        plot_errors(errors_,best_errors_)
    
n_iter=100
fit(n_iter, X, y)
# Out:
# Iteration:  1
# Weights:  [ 0.  -0.7  1.3]
# Misclassified Samples:  50
# Pocket Weights:  [ 0.  -0.7  1.3]
# Least # Misclassified Samples So far:  50
# Iteration:  2
# Weights:  [ 0.  -1.4  2.6]
# Misclassified Samples:  50
# Pocket Weights:  [ 0.  -1.4  2.6]
# Least # Misclassified Samples So far:  50
# Iteration:  3
# Weights:  [ 0.  -2.1  3.9]
# Misclassified Samples:  50
# Pocket Weights:  [ 0.  -2.1  3.9]
# Least # Misclassified Samples So far:  50
# Iteration:  4
# Weights:  [ 0.  -2.8  5.2]
# Misclassified Samples:  50
# Pocket Weights:  [ 0.  -2.8  5.2]
# Least # Misclassified Samples So far:  50
# Iteration:  5
# Weights:  [ 0.  -3.5  6.5]
# Misclassified Samples:  50
# Pocket Weights:  [ 0.  -3.5  6.5]
# Least # Misclassified Samples So far:  50
# Iteration:  6
# Weights:  [ 0.  -4.2  7.8]
# Misclassified Samples:  50
# Pocket Weights:  [ 0.  -4.2  7.8]
# Least # Misclassified Samples So far:  50
# Iteration:  7
# Weights:  [ 0.  -4.9  9.1]
# Misclassified Samples:  50
# Pocket Weights:  [ 0.  -4.9  9.1]
# Least # Misclassified Samples So far:  50
# Iteration:  8
# Weights:  [ 0.  -5.6 10.4]
# Misclassified Samples:  50
# Pocket Weights:  [ 0.  -5.6 10.4]
# Least # Misclassified Samples So far:  50
# Iteration:  9
# Weights:  [ 0.  -6.3 11.7]
# Misclassified Samples:  50
# Pocket Weights:  [ 0.  -6.3 11.7]
# Least # Misclassified Samples So far:  50
# Iteration:  10
# Weights:  [ 0. -7. 13.]
# Misclassified Samples:  50
# Pocket Weights:  [ 0. -7. 13.]
# Least # Misclassified Samples So far:  50
# Iteration:  11
# Weights:  [ 0.  -7.7 14.3]
# Misclassified Samples:  50
# Pocket Weights:  [ 0.  -7.7 14.3]
# Least # Misclassified Samples So far:  50
# Iteration:  12
# Weights:  [ 0.  -8.4 15.6]
# Misclassified Samples:  50
# Pocket Weights:  [ 0.  -8.4 15.6]
# Least # Misclassified Samples So far:  50
# Iteration:  13
# Weights:  [ 0.  -9.1 16.9]
# Misclassified Samples:  50
# Pocket Weights:  [ 0.  -9.1 16.9]
# Least # Misclassified Samples So far:  50
# Iteration:  14
# Weights:  [ 0.  -9.8 18.2]
# Misclassified Samples:  50
# Pocket Weights:  [ 0.  -9.8 18.2]
# Least # Misclassified Samples So far:  50
# Iteration:  15
# Weights:  [  0.  -10.5  19.5]
# Misclassified Samples:  50
# Pocket Weights:  [  0.  -10.5  19.5]
# Least # Misclassified Samples So far:  50
# Iteration:  16
# Weights:  [  0.  -11.2  20.8]
# Misclassified Samples:  50
# Pocket Weights:  [  0.  -11.2  20.8]
# Least # Misclassified Samples So far:  50
# Iteration:  17
# Weights:  [  0.  -11.9  22.1]
# Misclassified Samples:  50
# Pocket Weights:  [  0.  -11.9  22.1]
# Least # Misclassified Samples So far:  50
# Iteration:  18
# Weights:  [  0.  -12.6  23.4]
# Misclassified Samples:  50
# Pocket Weights:  [  0.  -12.6  23.4]
# Least # Misclassified Samples So far:  50
# Iteration:  19
# Weights:  [  0.  -13.3  24.7]
# Misclassified Samples:  50
# Pocket Weights:  [  0.  -13.3  24.7]
# Least # Misclassified Samples So far:  50
# Iteration:  20
# Weights:  [  0. -14.  26.]
# Misclassified Samples:  50
# Pocket Weights:  [  0. -14.  26.]
# Least # Misclassified Samples So far:  50
# Iteration:  21
# Weights:  [  0.  -14.7  27.3]
# Misclassified Samples:  50
# Pocket Weights:  [  0.  -14.7  27.3]
# Least # Misclassified Samples So far:  50
# Iteration:  22
# Weights:  [  0.  -15.4  28.6]
# Misclassified Samples:  50
# Pocket Weights:  [  0.  -15.4  28.6]
# Least # Misclassified Samples So far:  50
# Iteration:  23
# Weights:  [  0.  -16.6  29. ]
# Misclassified Samples:  50
# Pocket Weights:  [  0.  -16.6  29. ]
# Least # Misclassified Samples So far:  50
# Iteration:  24
# Weights:  [  0.  -17.3  30.3]
# Misclassified Samples:  50
# Pocket Weights:  [  0.  -17.3  30.3]
# Least # Misclassified Samples So far:  50
# Iteration:  25
# Weights:  [  0.  -18.   31.6]
# Misclassified Samples:  50
# Pocket Weights:  [  0.  -18.   31.6]
# Least # Misclassified Samples So far:  50
# Iteration:  26
# Weights:  [  0.  -19.2  32. ]
# Misclassified Samples:  49
# Pocket Weights:  [  0.  -19.2  32. ]
# Least # Misclassified Samples So far:  49
# Iteration:  27
# Weights:  [  0.  -19.9  33.3]
# Misclassified Samples:  49
# Pocket Weights:  [  0.  -19.9  33.3]
# Least # Misclassified Samples So far:  49
# Iteration:  28
# Weights:  [  0.  -21.1  33.7]
# Misclassified Samples:  48
# Pocket Weights:  [  0.  -21.1  33.7]
# Least # Misclassified Samples So far:  48
# Iteration:  29
# Weights:  [  0.  -21.8  35. ]
# Misclassified Samples:  48
# Pocket Weights:  [  0.  -21.8  35. ]
# Least # Misclassified Samples So far:  48
# Iteration:  30
# Weights:  [  0.  -22.5  36.3]
# Misclassified Samples:  48
# Pocket Weights:  [  0.  -22.5  36.3]
# Least # Misclassified Samples So far:  48
# Iteration:  31
# Weights:  [  0.  -23.7  36.7]
# Misclassified Samples:  47
# Pocket Weights:  [  0.  -23.7  36.7]
# Least # Misclassified Samples So far:  47
# Iteration:  32
# Weights:  [  0.  -24.4  38. ]
# Misclassified Samples:  48
# Pocket Weights:  [  0.  -23.7  36.7]
# Least # Misclassified Samples So far:  47
# Iteration:  33
# Weights:  [  0.  -25.6  38.4]
# Misclassified Samples:  44
# Pocket Weights:  [  0.  -25.6  38.4]
# Least # Misclassified Samples So far:  44
# Iteration:  34
# Weights:  [  0.  -26.3  39.7]
# Misclassified Samples:  44
# Pocket Weights:  [  0.  -26.3  39.7]
# Least # Misclassified Samples So far:  44
# Iteration:  35
# Weights:  [  0. -27.  41.]
# Misclassified Samples:  45
# Pocket Weights:  [  0.  -26.3  39.7]
# Least # Misclassified Samples So far:  44
# Iteration:  36
# Weights:  [  0.  -28.2  41.4]
# Misclassified Samples:  37
# Pocket Weights:  [  0.  -28.2  41.4]
# Least # Misclassified Samples So far:  37
# Iteration:  37
# Weights:  [  0.  -28.8  42. ]
# Misclassified Samples:  37
# Pocket Weights:  [  0.  -28.8  42. ]
# Least # Misclassified Samples So far:  37
# Iteration:  38
# Weights:  [  0.  -29.4  42.6]
# Misclassified Samples:  36
# Pocket Weights:  [  0.  -29.4  42.6]
# Least # Misclassified Samples So far:  36
# Iteration:  39
# Weights:  [  0.  -30.   43.2]
# Misclassified Samples:  34
# Pocket Weights:  [  0.  -30.   43.2]
# Least # Misclassified Samples So far:  34
# Iteration:  40
# Weights:  [  0.  -30.6  43.8]
# Misclassified Samples:  31
# Pocket Weights:  [  0.  -30.6  43.8]
# Least # Misclassified Samples So far:  31
# Iteration:  41
# Weights:  [  0.  -31.2  44.4]
# Misclassified Samples:  29
# Pocket Weights:  [  0.  -31.2  44.4]
# Least # Misclassified Samples So far:  29
# Iteration:  42
# Weights:  [  0.  -31.8  45. ]
# Misclassified Samples:  27
# Pocket Weights:  [  0.  -31.8  45. ]
# Least # Misclassified Samples So far:  27
# Iteration:  43
# Weights:  [  0.  -32.4  46.1]
# Misclassified Samples:  29
# Pocket Weights:  [  0.  -31.8  45. ]
# Least # Misclassified Samples So far:  27
# Iteration:  44
# Weights:  [  0.  -33.   46.7]
# Misclassified Samples:  27
# Pocket Weights:  [  0.  -33.   46.7]
# Least # Misclassified Samples So far:  27
# Iteration:  45
# Weights:  [  0.  -33.6  47.8]
# Misclassified Samples:  29
# Pocket Weights:  [  0.  -33.   46.7]
# Least # Misclassified Samples So far:  27
# Iteration:  46
# Weights:  [  0.  -34.2  48.4]
# Misclassified Samples:  27
# Pocket Weights:  [  0.  -34.2  48.4]
# Least # Misclassified Samples So far:  27
# Iteration:  47
# Weights:  [  0.  -35.3  48.6]
# Misclassified Samples:  21
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  48
# Weights:  [  0.  -35.   49.7]
# Misclassified Samples:  28
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  49
# Weights:  [  0.  -36.1  49.9]
# Misclassified Samples:  22
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  50
# Weights:  [  0.  -35.8  51. ]
# Misclassified Samples:  29
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  51
# Weights:  [  0.  -36.4  51.6]
# Misclassified Samples:  28
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  52
# Weights:  [  0.  -37.5  51.8]
# Misclassified Samples:  22
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  53
# Weights:  [  0.  -37.2  52.9]
# Misclassified Samples:  28
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  54
# Weights:  [  0.  -38.3  53.1]
# Misclassified Samples:  22
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  55
# Weights:  [  0.  -38.   54.2]
# Misclassified Samples:  30
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  56
# Weights:  [  0.  -38.6  54.8]
# Misclassified Samples:  28
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  57
# Weights:  [  0.  -39.7  55. ]
# Misclassified Samples:  22
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  58
# Weights:  [  0.  -39.4  56.1]
# Misclassified Samples:  29
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  59
# Weights:  [  0.  -40.   56.7]
# Misclassified Samples:  28
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  60
# Weights:  [  0.  -41.1  56.9]
# Misclassified Samples:  22
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  61
# Weights:  [  0.  -40.8  58. ]
# Misclassified Samples:  28
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  62
# Weights:  [  0.  -41.9  58.2]
# Misclassified Samples:  22
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  63
# Weights:  [  0.  -40.3  60.1]
# Misclassified Samples:  42
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  64
# Weights:  [  0.  -40.2  61.3]
# Misclassified Samples:  46
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  65
# Weights:  [  0.  -40.4  62.6]
# Misclassified Samples:  47
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  66
# Weights:  [  0.  -40.6  63.9]
# Misclassified Samples:  48
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  67
# Weights:  [  0.  -40.9  65.3]
# Misclassified Samples:  48
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  68
# Weights:  [  0.  -40.3  67.2]
# Misclassified Samples:  49
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  69
# Weights:  [  0.  -40.3  68.2]
# Misclassified Samples:  49
# Pocket Weights:  [  0.  -35.3  48.6]
# Least # Misclassified Samples So far:  21
# Iteration:  70
# Weights:  [ -1.  -47.2  64.1]
# Misclassified Samples:  16
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  71
# Weights:  [ -1.  -47.1  64.7]
# Misclassified Samples:  19
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  72
# Weights:  [ -1.  -47.   65.3]
# Misclassified Samples:  22
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  73
# Weights:  [ -1.  -45.4  67.2]
# Misclassified Samples:  37
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  74
# Weights:  [ -1.  -45.   68.7]
# Misclassified Samples:  45
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  75
# Weights:  [ -1.  -45.2  70. ]
# Misclassified Samples:  47
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  76
# Weights:  [ -1.  -45.5  71.4]
# Misclassified Samples:  48
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  77
# Weights:  [ -1.  -46.   72.2]
# Misclassified Samples:  48
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  78
# Weights:  [ -1.  -46.5  73. ]
# Misclassified Samples:  48
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  79
# Weights:  [ -1.  -47.1  73.8]
# Misclassified Samples:  48
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  80
# Weights:  [ -1.  -47.7  74.6]
# Misclassified Samples:  48
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  81
# Weights:  [ -1.  -48.3  75.4]
# Misclassified Samples:  47
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  82
# Weights:  [ -1.  -48.9  76.2]
# Misclassified Samples:  47
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  83
# Weights:  [ -1.  -49.5  77. ]
# Misclassified Samples:  47
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  84
# Weights:  [ -1.  -50.1  77.8]
# Misclassified Samples:  47
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  85
# Weights:  [ -1.  -50.8  78.5]
# Misclassified Samples:  47
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  86
# Weights:  [ -1.  -51.4  79.3]
# Misclassified Samples:  47
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  87
# Weights:  [ -1.  -52.   80.1]
# Misclassified Samples:  47
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  88
# Weights:  [ -1.  -52.6  80.9]
# Misclassified Samples:  47
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  89
# Weights:  [ -1.  -53.2  81.7]
# Misclassified Samples:  47
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  90
# Weights:  [ -1.  -53.8  82.5]
# Misclassified Samples:  47
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  91
# Weights:  [ -1.  -54.4  83.3]
# Misclassified Samples:  47
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  92
# Weights:  [ -1.  -55.   84.1]
# Misclassified Samples:  46
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  93
# Weights:  [ -1.  -55.7  84.8]
# Misclassified Samples:  45
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  94
# Weights:  [ -1.  -56.3  85.6]
# Misclassified Samples:  44
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  95
# Weights:  [ -1.  -56.9  86.4]
# Misclassified Samples:  44
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  96
# Weights:  [ -1.  -57.5  87.2]
# Misclassified Samples:  44
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  97
# Weights:  [ -1.  -58.1  88. ]
# Misclassified Samples:  44
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  98
# Weights:  [ -1.  -58.7  88.8]
# Misclassified Samples:  44
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  99
# Weights:  [ -1.  -59.3  89.6]
# Misclassified Samples:  44
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
# Iteration:  100
# Weights:  [ -1.  -59.9  90.4]
# Misclassified Samples:  44
# Pocket Weights:  [ -1.  -47.2  64.1]
# Least # Misclassified Samples So far:  16
